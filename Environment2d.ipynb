# %%
from Parser import Parser
from ipycanvas import Canvas
from typing import Dict, Callable, Tuple, List
import ipywidgets as widgets
import numpy as np
import math

MOVE_ACTION = 'move'
ZOOM_ACTION = 'zoom'
SELECT_ACTION = 'select'

def defaultColorMap(cells, variables):
    return [
        ('#004400', 'green', cells[variables['cycle_model']] == 5),
        ('brown', 'black', cells[variables['cycle_model']] == 100),
        ('#440000', 'red', cells[variables['cycle_model']] == 101)
    ]

def count(array):
    dic = {}
    for num in array:
        if not num in dic:
            dic[num] = 0
        dic[num] += 1
    return dic
    

class Interactor2D:
    def __init__(self, parser, width: int = 500, height: int = 400, colorMap = defaultColorMap):
        self._currentFrame = parser.getFrameRange()[0]
        self._canvas = Canvas(width=width, height=height)
        self._parser = parser
        self._colorMap = colorMap
        self._height = height
        self._width = width
        
        frame = parser.getFrame(self._currentFrame)
        mesh = frame.environment.mesh
        self._zoom = max((mesh.boundsX[1] - mesh.boundsX[0]) / width, (mesh.boundsY[1] - mesh.boundsY[0]) / height)
        
        self._xOffset = mesh.boundsX[0]
        self._yOffset = mesh.boundsY[0]
        self._selectedCell = None
        
        self._clicking = False
        self._dragStartX = 0
        self._dragStartY = 0
        self._actionOriginX = 0
        self._actionOriginY = 0
        
        self._canvas.on_mouse_down(self.onMouseDown)
        self._canvas.on_mouse_move(self.onMouseMove)
        self._canvas.on_mouse_up(self.onMouseUp)
        self._canvas.on_mouse_out(self.onMouseOut)
        
        self.action = MOVE_ACTION
        
        self._buttons = widgets.RadioButtons(
            options=[MOVE_ACTION, ZOOM_ACTION, SELECT_ACTION],
            value=self.action,
            description='Mouse Action:',
            disabled=False,
        )
        self._buttons.observe(self.onToolChange, names='value')
        
        self._frameSelector = widgets.IntSlider(
            value=self._currentFrame,
            min=parser.getFrameRange()[0],
            max=parser.getFrameRange()[1] - 1,
            step=1,
            description='Frame:',
            disabled=False,
            continuous_update=False,
            orientation='horizontal',
            readout=True,
            readout_format='d'
        )
        self._frameSelector.observe(self.onFrameChange, names='value')
        
        self.update()
    
    def update(self):
        self._canvas.clear()
        
        canvas = self._canvas
        
        frame = self._parser.getFrame(self._currentFrame)
    
        cells = frame.cells.data
        cellVariables = frame.cells.variables
        
        canvas.stroke_style = 'blue'

        x = (cells[cellVariables['position.x']] - self._xOffset) / self._zoom
        y = (cells[cellVariables['position.y']] - self._yOffset) / self._zoom
        r = self.radiusOfCells(cells, cellVariables) / self._zoom
        
        combined = np.array([x, y, r])
        
        for fill, stroke, indices in self._colorMap(cells, cellVariables):
            split = combined[:,indices]
            if split.shape[0] == 0:
                continue
            x, y, r = split
            canvas.fill_style = fill
            canvas.fill_circles(x, y, r)
            canvas.stroke_style = stroke
            canvas.stroke_circles(x, y, r)
            
        
        canvas.fill_style = '#A0A0A0'
        canvas.font = '10px serif'
        canvas.fill_text(f"(x: {self._xOffset}, y: {self._yOffset}, s: {self._zoom}, c: {self._selectedCell})", 10, self._height - 10)
        
    
    def onMouseDown(self, x: int, y: int):
        self._dragStartX = x
        self._dragStartY = y
        self._envActionOriginX = x * self._zoom + self._xOffset
        self._envActionOriginY = y * self._zoom + self._yOffset
        self._actionOriginX = x
        self._actionOriginY = y
        self._actionOriginZoom = self._zoom
        
        if self.action == SELECT_ACTION:
            self.selectCell(self._envActionOriginX, self._envActionOriginY)
        else:
            self._clicking = True
    
    def onMouseUp(self, x: int, y: int):
        self._clicking = False
    
    def onMouseOut(self, x: int, y: int):
        self._clicking = False
    
    def onMouseMove(self, x: int, y: int):
        if self._clicking:
            if self.action == MOVE_ACTION:
                self._xOffset -= (x - self._dragStartX) * self._zoom
                self._yOffset -= (y - self._dragStartY) * self._zoom
            elif self.action == ZOOM_ACTION:
                self._zoom = max(self._actionOriginZoom * 2 ** ((self._actionOriginY - y) / 25), 0.0001)
                self._xOffset = self._envActionOriginX - self._actionOriginX * self._zoom
                self._yOffset = self._envActionOriginY - self._actionOriginY * self._zoom
                
            self._dragStartX = x
            self._dragStartY = y
            self.update()
    
    def onToolChange(self, action):
        self.action = action.new
    
    def onFrameChange(self, action):
        self._currentFrame = action.new
        self.update()
    
    def selectCell(self, x: float, y: float):
        frame = self._parser.getFrame(self._currentFrame)
    
        cells = frame.cells.data
        cellVariables = frame.cells.variables
        
        distances = np.sqrt(np.square(x - cells[cellVariables['position.x']]) + np.square(y - cells[cellVariables['position.y']])) - self.radiusOfCells(cells, cellVariables)
        minIndex = np.argmin(distances)
        
        if distances[minIndex] <= 0:
            self._selectedCell = cells[cellVariables['ID'], minIndex]
            self.update()
        
        
 
    def radiusOfCells(self, cells, variables):
        return (cells[variables['total_volume']] * (3 / ( 4 * math.pi))) ** (1 / 3)

    def show(self):
        display(self._canvas, self._buttons, self._frameSelector)
            



def InteractiveEnvironment(outputPath: str, width: int = 500, height: int = 400):
    parser = Parser(outputPath)
    if parser.getFrame(parser.getFrameRange()[0]).environment.is2D:
        return Interactor2D(parser, width, height)

# %%
env = InteractiveEnvironment('./sample-output', width=800, height=800)
env.show()
# Out:
# Canvas(height=800, width=800)
# RadioButtons(description='Mouse Action:', options=('move', 'zoom', 'select'), value='move')
# IntSlider(value=0, continuous_update=False, description='Frame:', max=9)

# %%
help(Canvas)
# Out:
# Help on class Canvas in module ipycanvas.canvas:
#
# class Canvas(_CanvasBase)
#  |  Canvas(*args, **kwargs)
#  |
#  |  Create a Canvas widget.
#  |
#  |  Args:
#  |      width (int): The width (in pixels) of the canvas
#  |      height (int): The height (in pixels) of the canvas
#  |      caching (boolean): Whether commands should be cached or not
#  |
#  |  Method resolution order:
#  |      Canvas
#  |      _CanvasBase
#  |      ipywidgets.widgets.domwidget.DOMWidget
#  |      ipywidgets.widgets.widget.Widget
#  |      ipywidgets.widgets.widget.LoggingHasTraits
#  |      traitlets.traitlets.HasTraits
#  |      traitlets.traitlets.HasDescriptors
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, *args, **kwargs)
#  |      Create a Canvas widget.
#  |
#  |  __setattr__(self, name, value)
#  |      Implement setattr(self, name, value).
#  |
#  |  arc(self, x, y, radius, start_angle, end_angle, anticlockwise=False)
#  |      Add a circular arc centered at ``(x, y)`` with a radius of ``radius`` to the current path.
#  |
#  |      The path starts at ``start_angle`` and ends at ``end_angle``, and travels in the direction given by
#  |      ``anticlockwise`` (defaulting to clockwise: ``False``).
#  |
#  |  arc_to(self, x1, y1, x2, y2, radius)
#  |      Add a circular arc to the current path.
#  |
#  |      Using the given control points ``(x1, y1)`` and ``(x2, y2)`` and the ``radius``.
#  |
#  |  begin_path(self)
#  |      Call this method when you want to create a new path.
#  |
#  |  bezier_curve_to(self, cp1x, cp1y, cp2x, cp2y, x, y)
#  |      Add a cubic Bezier curve to the current path.
#  |
#  |      It requires three points: the first two are control points and the third one is the end point.
#  |      The starting point is the latest point in the current path, which can be changed using move_to()
#  |      before creating the Bezier curve.
#  |
#  |  clear(self)
#  |      Clear the entire canvas. This is the same as calling ``clear_rect(0, 0, canvas.width, canvas.height)``.
#  |
#  |  clear_rect(self, x, y, width, height=None)
#  |      Clear the specified rectangular area of size ``(width, height)`` at the ``(x, y)`` position, making it fully transparent.
#  |
#  |  clip(self)
#  |      Turn the path currently being built into the current clipping path.
#  |
#  |      You can use clip() instead of close_path() to close a path and turn it into a clipping
#  |      path instead of stroking or filling the path.
#  |
#  |  close_path(self)
#  |      Add a straight line from the current point to the start of the current path.
#  |
#  |      If the shape has already been closed or has only one point, this function does nothing.
#  |      This method doesn't draw anything to the canvas directly. You can render the path using the stroke() or fill() methods.
#  |
#  |  create_image_data(self, width, height)
#  |      Create a NumPy array of shape (width, height, 4) representing a table of pixel colors.
#  |
#  |  create_linear_gradient(self, x0, y0, x1, y1, color_stops)
#  |      Create a LinearGradient object given the start point, end point, and color stops.
#  |
#  |      Args:
#  |          x0 (float): The x-axis coordinate of the start point.
#  |          y0 (float): The y-axis coordinate of the start point.
#  |          x1 (float): The x-axis coordinate of the end point.
#  |          y1 (float): The y-axis coordinate of the end point.
#  |          color_stops (list): The list of color stop tuples (offset, color) defining the gradient.
#  |
#  |  create_pattern(self, image, repetition='repeat')
#  |      Create a Pattern.
#  |
#  |      Args:
#  |          image (Canvas or MultiCanvas or ipywidgets.Image): The source to be used as the pattern's image
#  |          repetition (str): A string indicating how to repeat the pattern's image, can be "repeat" (both directions), "repeat-x" (horizontal only), "repeat-y" (vertical only), "no-repeat" (neither direction)
#  |
#  |  create_radial_gradient(self, x0, y0, r0, x1, y1, r1, color_stops)
#  |      Create a RadialGradient object given the start circle, end circle and color stops.
#  |
#  |      Args:
#  |          x0 (float): The x-axis coordinate of the start circle.
#  |          y0 (float): The y-axis coordinate of the start circle.
#  |          r0 (float): The radius of the start circle.
#  |          x1 (float): The x-axis coordinate of the end circle.
#  |          y1 (float): The y-axis coordinate of the end circle.
#  |          r1 (float): The radius of the end circle.
#  |          color_stops (list): The list of color stop tuples (offset, color) defining the gradient.
#  |
#  |  draw_image(self, image, x=0, y=0, width=None, height=None)
#  |      Draw an ``image`` on the Canvas at the coordinates (``x``, ``y``) and scale it to (``width``, ``height``).
#  |
#  |  ellipse(self, x, y, radius_x, radius_y, rotation, start_angle, end_angle, anticlockwise=False)
#  |      Add an ellipse centered at ``(x, y)`` with the radii ``radius_x`` and ``radius_y`` to the current path.
#  |
#  |      The path starts at ``start_angle`` and ends at ``end_angle``, and travels in the direction given by
#  |      ``anticlockwise`` (defaulting to clockwise: ``False``).
#  |
#  |  fill(self, rule_or_path='nonzero')
#  |      Fill the current path with the current ``fill_style`` and given the rule, or fill the given Path2D.
#  |
#  |      Possible rules are ``nonzero`` and ``evenodd``.
#  |
#  |  fill_arc(self, x, y, radius, start_angle, end_angle, anticlockwise=False)
#  |      Draw a filled arc centered at ``(x, y)`` with a radius of ``radius`` from ``start_angle`` to ``end_angle``.
#  |
#  |  fill_arcs(self, x, y, radius, start_angle, end_angle, anticlockwise=False)
#  |      Draw filled arcs centered at ``(x, y)`` with a radius of ``radius``.
#  |
#  |      Where ``x``, ``y``, ``radius`` and other arguments are NumPy arrays, lists or scalar values.
#  |
#  |  fill_circle(self, x, y, radius)
#  |      Draw a filled circle centered at ``(x, y)`` with a radius of ``radius``.
#  |
#  |  fill_circles(self, x, y, radius)
#  |      Draw filled circles centered at ``(x, y)`` with a radius of ``radius``.
#  |
#  |      Where ``x``, ``y``, ``radius`` and other arguments are NumPy arrays, lists or scalar values.
#  |
#  |  fill_polygon(self, points)
#  |      Fill a polygon from a list of points ``[(x1, y1), (x2, y2), ..., (xn, yn)]``.
#  |
#  |  fill_rect(self, x, y, width, height=None)
#  |      Draw a filled rectangle of size ``(width, height)`` at the ``(x, y)`` position.
#  |
#  |  fill_rects(self, x, y, width, height=None)
#  |      Draw filled rectangles of sizes ``(width, height)`` at the ``(x, y)`` positions.
#  |
#  |      Where ``x``, ``y``, ``width`` and ``height`` arguments are NumPy arrays, lists or scalar values.
#  |      If ``height`` is None, it is set to the same value as width.
#  |
#  |  fill_text(self, text, x, y, max_width=None)
#  |      Fill a given text at the given ``(x, y)`` position. Optionally with a maximum width to draw.
#  |
#  |  flush(self)
#  |      Flush all the cached commands and clear the cache.
#  |
#  |  get_line_dash(self)
#  |      Return the current line dash pattern array containing an even number of non-negative numbers.
#  |
#  |  line_to(self, x, y)
#  |      Add a straight line to the current path by connecting the path's last point to the specified ``(x, y)`` coordinates.
#  |
#  |      Like other methods that modify the current path, this method does not directly render anything. To
#  |      draw the path onto the canvas, you can use the fill() or stroke() methods.
#  |
#  |  move_to(self, x, y)
#  |      Move the "pen" to the given ``(x, y)`` coordinates.
#  |
#  |  on_client_ready(self, callback, remove=False)
#  |      Register a callback that will be called when a new client is ready to receive draw commands.
#  |
#  |      When a new client connects to the kernel he will get an empty Canvas (because the canvas is
#  |      almost stateless, the new client does not know what draw commands were previously sent). So
#  |      this function is useful for replaying your drawing whenever a new client connects and is
#  |      ready to receive draw commands.
#  |
#  |  on_mouse_down(self, callback, remove=False)
#  |      Register a callback that will be called on mouse click down.
#  |
#  |  on_mouse_move(self, callback, remove=False)
#  |      Register a callback that will be called on mouse move.
#  |
#  |  on_mouse_out(self, callback, remove=False)
#  |      Register a callback that will be called on mouse out of the canvas.
#  |
#  |  on_mouse_up(self, callback, remove=False)
#  |      Register a callback that will be called on mouse click up.
#  |
#  |  on_touch_cancel(self, callback, remove=False)
#  |      Register a callback that will be called on touch cancel.
#  |
#  |  on_touch_end(self, callback, remove=False)
#  |      Register a callback that will be called on touch end (a finger is not touching the screen anymore).
#  |
#  |  on_touch_move(self, callback, remove=False)
#  |      Register a callback that will be called on touch move (finger moving on the screen).
#  |
#  |  on_touch_start(self, callback, remove=False)
#  |      Register a callback that will be called on touch start (new finger on the screen).
#  |
#  |  put_image_data(self, image_data, x=0, y=0)
#  |      Draw an image on the Canvas.
#  |
#  |      ``image_data`` should be  a NumPy array containing the image to draw and ``x`` and ``y`` the pixel position where to
#  |      draw. Unlike the CanvasRenderingContext2D.putImageData method, this method **is** affected by the canvas transformation
#  |      matrix, and supports transparency.
#  |
#  |  quadratic_curve_to(self, cp1x, cp1y, x, y)
#  |      Add a quadratic Bezier curve to the current path.
#  |
#  |      It requires two points: the first one is a control point and the second one is the end point.
#  |      The starting point is the latest point in the current path, which can be changed using move_to()
#  |      before creating the quadratic Bezier curve.
#  |
#  |  rect(self, x, y, width, height)
#  |      Add a rectangle of size ``(width, height)`` at the ``(x, y)`` position in the current path.
#  |
#  |  reset_transform(self)
#  |      Reset the current transform to the identity matrix.
#  |
#  |      This is the same as calling: set_transform(1, 0, 0, 1, 0, 0).
#  |
#  |  restore(self)
#  |      Restore the most recently saved canvas state.
#  |
#  |  rotate(self, angle)
#  |      Rotate the canvas clockwise around the current origin by the ``angle`` number of radians.
#  |
#  |  save(self)
#  |      Save the entire state of the canvas.
#  |
#  |  scale(self, x, y=None)
#  |      Scale the canvas units by ``x`` horizontally and by ``y`` vertically. Both parameters are real numbers.
#  |
#  |      If ``y`` is not provided, it is defaulted to the same value as ``x``.
#  |      Values that are smaller than 1.0 reduce the unit size and values above 1.0 increase the unit size.
#  |      Values of 1.0 leave the units the same size.
#  |
#  |  set_line_dash(self, segments)
#  |      Set the current line dash pattern.
#  |
#  |  set_transform(self, a, b, c, d, e, f)
#  |      Reset the current transform to the identity matrix, and then invokes the transform() method with the same arguments.
#  |
#  |      This basically undoes the current transformation, then sets the specified transform, all in one step.
#  |
#  |  sleep(self, time)
#  |      Make the Canvas sleep for `time` milliseconds.
#  |
#  |  stroke(self)
#  |      Stroke (outlines) the current path with the current ``stroke_style``.
#  |
#  |  stroke_arc(self, x, y, radius, start_angle, end_angle, anticlockwise=False)
#  |      Draw an arc outline centered at ``(x, y)`` with a radius of ``radius``.
#  |
#  |  stroke_arcs(self, x, y, radius, start_angle, end_angle, anticlockwise=False)
#  |      Draw an arc outlines centered at ``(x, y)`` with a radius of ``radius``.
#  |
#  |      Where ``x``, ``y``, ``radius`` and other arguments are NumPy arrays, lists or scalar values.
#  |
#  |  stroke_circle(self, x, y, radius)
#  |      Draw a circle centered at ``(x, y)`` with a radius of ``radius``.
#  |
#  |  stroke_circles(self, x, y, radius)
#  |      Draw a circle outlines centered at ``(x, y)`` with a radius of ``radius``.
#  |
#  |      Where ``x``, ``y``, ``radius`` and other arguments are NumPy arrays, lists or scalar values.
#  |
#  |  stroke_line(self, x1, y1, x2, y2)
#  |      Draw a line from ``(x1, y1)`` to ``(x2, y2)``.
#  |
#  |  stroke_lines(self, points)
#  |      Draw a path of consecutive lines from a list of points ``[(x1, y1), (x2, y2), ..., (xn, yn)]``.
#  |
#  |  stroke_polygon(self, points)
#  |      Draw polygon outline from a list of points ``[(x1, y1), (x2, y2), ..., (xn, yn)]``.
#  |
#  |  stroke_rect(self, x, y, width, height=None)
#  |      Draw a rectangular outline of size ``(width, height)`` at the ``(x, y)`` position.
#  |
#  |  stroke_rects(self, x, y, width, height=None)
#  |      Draw a rectangular outlines of sizes ``(width, height)`` at the ``(x, y)`` positions.
#  |
#  |      Where ``x``, ``y``, ``width`` and ``height`` arguments are NumPy arrays, lists or scalar values.
#  |      If ``height`` is None, it is set to the same value as width.
#  |
#  |  stroke_text(self, text, x, y, max_width=None)
#  |      Stroke a given text at the given ``(x, y)`` position. Optionally with a maximum width to draw.
#  |
#  |  transform(self, a, b, c, d, e, f)
#  |      Multiply the current transformation matrix with the matrix described by its arguments.
#  |
#  |      The transformation matrix is described by:
#  |      ``[[a, c, e], [b, d, f], [0, 0, 1]]``.
#  |
#  |  translate(self, x, y)
#  |      Move the canvas and its origin on the grid.
#  |
#  |      ``x`` indicates the horizontal distance to move,
#  |      and ``y`` indicates how far to move the grid vertically.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  direction
#  |      An enum whose value must be in a given sequence.
#  |
#  |  fill_style
#  |      A trait type representing a Union type.
#  |
#  |  font
#  |      A trait for unicode strings.
#  |
#  |  global_alpha
#  |      A float trait.
#  |
#  |  global_composite_operation
#  |      An enum whose value must be in a given sequence.
#  |
#  |  line_cap
#  |      An enum whose value must be in a given sequence.
#  |
#  |  line_dash_offset
#  |      A float trait.
#  |
#  |  line_join
#  |      An enum whose value must be in a given sequence.
#  |
#  |  line_width
#  |      A float trait.
#  |
#  |  miter_limit
#  |      A float trait.
#  |
#  |  shadow_blur
#  |      A float trait.
#  |
#  |  shadow_color
#  |      A string holding a valid HTML color such as 'blue', '#060482', '#A80'
#  |
#  |  shadow_offset_x
#  |      A float trait.
#  |
#  |  shadow_offset_y
#  |      A float trait.
#  |
#  |  stroke_style
#  |      A trait type representing a Union type.
#  |
#  |  text_align
#  |      An enum whose value must be in a given sequence.
#  |
#  |  text_baseline
#  |      An enum whose value must be in a given sequence.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  ATTRS = {'direction': 6, 'fill_style': 0, 'font': 3, 'global_alpha': 2...
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from _CanvasBase:
#  |
#  |  get_image_data(self, x=0, y=0, width=None, height=None)
#  |      Return a NumPy array representing the underlying pixel data for a specified portion of the canvas.
#  |
#  |      This will throw an error if there is no ``image_data`` to retrieve, this happens when nothing was drawn yet or
#  |      when the ``sync_image_data`` attribute is not set to ``True``.
#  |      The returned value is a NumPy array containing the image data for the rectangle of the canvas specified. The
#  |      coordinates of the rectangle's top-left corner are (``x``, ``y``), while the coordinates of the bottom corner
#  |      are (``x + width``, ``y + height``).
#  |
#  |  to_file(self, filename)
#  |      Save the current Canvas image to a PNG file.
#  |
#  |      This will raise an exception if there is no image to save (_e.g._ if ``image_data`` is ``None``).
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from _CanvasBase:
#  |
#  |  height
#  |      A casting version of the int trait.
#  |
#  |  image_data
#  |      A trait for byte strings.
#  |
#  |  size
#  |      Get the canvas size.
#  |
#  |  sync_image_data
#  |      A boolean (True, False) trait.
#  |
#  |  width
#  |      A casting version of the int trait.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from ipywidgets.widgets.domwidget.DOMWidget:
#  |
#  |  add_class(self, className)
#  |      Adds a class to the top level element of the widget.
#  |
#  |      Doesn't add the class if it already exists.
#  |
#  |  remove_class(self, className)
#  |      Removes a class from the top level element of the widget.
#  |
#  |      Doesn't remove the class if it doesn't exist.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from ipywidgets.widgets.domwidget.DOMWidget:
#  |
#  |  layout
#  |      An instance trait which coerces a dict to an instance.
#  |
#  |      This lets the instance be specified as a dict, which is used
#  |      to initialize the instance.
#  |
#  |      Also, we default to a trivial instance, even if args and kwargs
#  |      is not specified.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from ipywidgets.widgets.widget.Widget:
#  |
#  |  __del__(self)
#  |      Object disposal
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  add_traits(self, **traits)
#  |      Dynamically add trait attributes to the Widget.
#  |
#  |  close(self)
#  |      Close method.
#  |
#  |      Closes the underlying comm.
#  |      When the comm is closed, all of the widget views are automatically
#  |      removed from the front-end.
#  |
#  |  get_state(self, key=None, drop_defaults=False)
#  |      Gets the widget state, or a piece of it.
#  |
#  |      Parameters
#  |      ----------
#  |      key : unicode or iterable (optional)
#  |          A single property's name or iterable of property names to get.
#  |
#  |      Returns
#  |      -------
#  |      state : dict of states
#  |      metadata : dict
#  |          metadata for each field: {key: metadata}
#  |
#  |  get_view_spec(self)
#  |
#  |  hold_sync(self)
#  |      Hold syncing any state until the outermost context manager exits
#  |
#  |  notify_change(self, change)
#  |      Called when a property has changed.
#  |
#  |  on_displayed(self, callback, remove=False)
#  |      (Un)Register a widget displayed callback.
#  |
#  |      Parameters
#  |      ----------
#  |      callback: method handler
#  |          Must have a signature of::
#  |
#  |              callback(widget, **kwargs)
#  |
#  |          kwargs from display are passed through without modification.
#  |      remove: bool
#  |          True if the callback should be unregistered.
#  |
#  |  on_msg(self, callback, remove=False)
#  |      (Un)Register a custom msg receive callback.
#  |
#  |      Parameters
#  |      ----------
#  |      callback: callable
#  |          callback will be passed three arguments when a message arrives::
#  |
#  |              callback(widget, content, buffers)
#  |
#  |      remove: bool
#  |          True if the callback should be unregistered.
#  |
#  |  open(self)
#  |      Open a comm to the frontend if one isn't already open.
#  |
#  |  send(self, content, buffers=None)
#  |      Sends a custom msg to the widget model in the front-end.
#  |
#  |      Parameters
#  |      ----------
#  |      content : dict
#  |          Content of the message to send.
#  |      buffers : list of binary buffers
#  |          Binary buffers to send with message
#  |
#  |  send_state(self, key=None)
#  |      Sends the widget state, or a piece of it, to the front-end, if it exists.
#  |
#  |      Parameters
#  |      ----------
#  |      key : unicode, or iterable (optional)
#  |          A single property's name or iterable of property names to sync with the front-end.
#  |
#  |  set_state(self, sync_data)
#  |      Called when a state is received from the front-end.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from ipywidgets.widgets.widget.Widget:
#  |
#  |  close_all() from traitlets.traitlets.MetaHasTraits
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from ipywidgets.widgets.widget.Widget:
#  |
#  |  get_manager_state(drop_defaults=False, widgets=None)
#  |      Returns the full state for a widget manager for embedding
#  |
#  |      :param drop_defaults: when True, it will not include default value
#  |      :param widgets: list with widgets to include in the state (or all widgets when None)
#  |      :return:
#  |
#  |  handle_comm_opened(comm, msg)
#  |      Static method, called when a widget is constructed.
#  |
#  |  on_widget_constructed(callback)
#  |      Registers a callback to be called when a widget is constructed.
#  |
#  |      The callback must have the following signature:
#  |      callback(widget)
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from ipywidgets.widgets.widget.Widget:
#  |
#  |  model_id
#  |      Gets the model id of this widget.
#  |
#  |      If a Comm doesn't exist yet, a Comm will be created automagically.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from ipywidgets.widgets.widget.Widget:
#  |
#  |  comm
#  |      A trait whose value must be an instance of a specified class.
#  |
#  |      The value can also be an instance of a subclass of the specified class.
#  |
#  |      Subclasses can declare default classes by overriding the klass attribute
#  |
#  |  keys
#  |      An instance of a Python list.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from ipywidgets.widgets.widget.Widget:
#  |
#  |  widget_types = <ipywidgets.widgets.widget.WidgetRegistry object>
#  |
#  |  widgets = {'0f607d1074144b4a87df39a37a36ec80': Layout(), '445bd1eb9e3b...
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from ipywidgets.widgets.widget.LoggingHasTraits:
#  |
#  |  log
#  |      A trait whose value must be an instance of a specified class.
#  |
#  |      The value can also be an instance of a subclass of the specified class.
#  |
#  |      Subclasses can declare default classes by overriding the klass attribute
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from traitlets.traitlets.HasTraits:
#  |
#  |  __getstate__(self)
#  |
#  |  __setstate__(self, state)
#  |
#  |  has_trait(self, name)
#  |      Returns True if the object has a trait with the specified name.
#  |
#  |  hold_trait_notifications(self)
#  |      Context manager for bundling trait change notifications and cross
#  |      validation.
#  |
#  |      Use this when doing multiple trait assignments (init, config), to avoid
#  |      race conditions in trait notifiers requesting other trait values.
#  |      All trait notifications will fire after all values have been assigned.
#  |
#  |  observe(self, handler, names=traitlets.All, type='change')
#  |      Setup a handler to be called when a trait changes.
#  |
#  |      This is used to setup dynamic notifications of trait changes.
#  |
#  |      Parameters
#  |      ----------
#  |      handler : callable
#  |          A callable that is called when a trait changes. Its
#  |          signature should be ``handler(change)``, where ``change`` is a
#  |          dictionary. The change dictionary at least holds a 'type' key.
#  |          * ``type``: the type of notification.
#  |          Other keys may be passed depending on the value of 'type'. In the
#  |          case where type is 'change', we also have the following keys:
#  |          * ``owner`` : the HasTraits instance
#  |          * ``old`` : the old value of the modified trait attribute
#  |          * ``new`` : the new value of the modified trait attribute
#  |          * ``name`` : the name of the modified trait attribute.
#  |      names : list, str, All
#  |          If names is All, the handler will apply to all traits.  If a list
#  |          of str, handler will apply to all names in the list.  If a
#  |          str, the handler will apply just to that name.
#  |      type : str, All (default: 'change')
#  |          The type of notification to filter by. If equal to All, then all
#  |          notifications are passed to the observe handler.
#  |
#  |  on_trait_change(self, handler=None, name=None, remove=False)
#  |      DEPRECATED: Setup a handler to be called when a trait changes.
#  |
#  |      This is used to setup dynamic notifications of trait changes.
#  |
#  |      Static handlers can be created by creating methods on a HasTraits
#  |      subclass with the naming convention '_[traitname]_changed'.  Thus,
#  |      to create static handler for the trait 'a', create the method
#  |      _a_changed(self, name, old, new) (fewer arguments can be used, see
#  |      below).
#  |
#  |      If `remove` is True and `handler` is not specified, all change
#  |      handlers for the specified name are uninstalled.
#  |
#  |      Parameters
#  |      ----------
#  |      handler : callable, None
#  |          A callable that is called when a trait changes.  Its
#  |          signature can be handler(), handler(name), handler(name, new),
#  |          handler(name, old, new), or handler(name, old, new, self).
#  |      name : list, str, None
#  |          If None, the handler will apply to all traits.  If a list
#  |          of str, handler will apply to all names in the list.  If a
#  |          str, the handler will apply just to that name.
#  |      remove : bool
#  |          If False (the default), then install the handler.  If True
#  |          then unintall it.
#  |
#  |  set_trait(self, name, value)
#  |      Forcibly sets trait attribute, including read-only attributes.
#  |
#  |  setup_instance(*args, **kwargs)
#  |      This is called **before** self.__init__ is called.
#  |
#  |  trait_defaults(self, *names, **metadata)
#  |      Return a trait's default value or a dictionary of them
#  |
#  |      Notes
#  |      -----
#  |      Dynamically generated default values may
#  |      depend on the current state of the object.
#  |
#  |  trait_has_value(self, name)
#  |      Returns True if the specified trait has a value.
#  |
#  |      This will return false even if ``getattr`` would return a
#  |      dynamically generated default value. These default values
#  |      will be recognized as existing only after they have been
#  |      generated.
#  |
#  |      Example
#  |
#  |      .. code-block:: python
#  |
#  |          class MyClass(HasTraits):
#  |              i = Int()
#  |
#  |          mc = MyClass()
#  |          assert not mc.trait_has_value("i")
#  |          mc.i # generates a default value
#  |          assert mc.trait_has_value("i")
#  |
#  |  trait_metadata(self, traitname, key, default=None)
#  |      Get metadata values for trait by key.
#  |
#  |  trait_names(self, **metadata)
#  |      Get a list of all the names of this class' traits.
#  |
#  |  trait_values(self, **metadata)
#  |      A ``dict`` of trait names and their values.
#  |
#  |      The metadata kwargs allow functions to be passed in which
#  |      filter traits based on metadata values.  The functions should
#  |      take a single value as an argument and return a boolean.  If
#  |      any function returns False, then the trait is not included in
#  |      the output.  If a metadata key doesn't exist, None will be passed
#  |      to the function.
#  |
#  |      Returns
#  |      -------
#  |      A ``dict`` of trait names and their values.
#  |
#  |      Notes
#  |      -----
#  |      Trait values are retrieved via ``getattr``, any exceptions raised
#  |      by traits or the operations they may trigger will result in the
#  |      absence of a trait value in the result ``dict``.
#  |
#  |  traits(self, **metadata)
#  |      Get a ``dict`` of all the traits of this class.  The dictionary
#  |      is keyed on the name and the values are the TraitType objects.
#  |
#  |      The TraitTypes returned don't know anything about the values
#  |      that the various HasTrait's instances are holding.
#  |
#  |      The metadata kwargs allow functions to be passed in which
#  |      filter traits based on metadata values.  The functions should
#  |      take a single value as an argument and return a boolean.  If
#  |      any function returns False, then the trait is not included in
#  |      the output.  If a metadata key doesn't exist, None will be passed
#  |      to the function.
#  |
#  |  unobserve(self, handler, names=traitlets.All, type='change')
#  |      Remove a trait change handler.
#  |
#  |      This is used to unregister handlers to trait change notifications.
#  |
#  |      Parameters
#  |      ----------
#  |      handler : callable
#  |          The callable called when a trait attribute changes.
#  |      names : list, str, All (default: All)
#  |          The names of the traits for which the specified handler should be
#  |          uninstalled. If names is All, the specified handler is uninstalled
#  |          from the list of notifiers corresponding to all changes.
#  |      type : str or All (default: 'change')
#  |          The type of notification to filter by. If All, the specified handler
#  |          is uninstalled from the list of notifiers corresponding to all types.
#  |
#  |  unobserve_all(self, name=traitlets.All)
#  |      Remove trait change handlers of any type for the specified name.
#  |      If name is not specified, removes all trait notifiers.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from traitlets.traitlets.HasTraits:
#  |
#  |  class_own_trait_events(name) from traitlets.traitlets.MetaHasTraits
#  |      Get a dict of all event handlers defined on this class, not a parent.
#  |
#  |      Works like ``event_handlers``, except for excluding traits from parents.
#  |
#  |  class_own_traits(**metadata) from traitlets.traitlets.MetaHasTraits
#  |      Get a dict of all the traitlets defined on this class, not a parent.
#  |
#  |      Works like `class_traits`, except for excluding traits from parents.
#  |
#  |  class_trait_names(**metadata) from traitlets.traitlets.MetaHasTraits
#  |      Get a list of all the names of this class' traits.
#  |
#  |      This method is just like the :meth:`trait_names` method,
#  |      but is unbound.
#  |
#  |  class_traits(**metadata) from traitlets.traitlets.MetaHasTraits
#  |      Get a ``dict`` of all the traits of this class.  The dictionary
#  |      is keyed on the name and the values are the TraitType objects.
#  |
#  |      This method is just like the :meth:`traits` method, but is unbound.
#  |
#  |      The TraitTypes returned don't know anything about the values
#  |      that the various HasTrait's instances are holding.
#  |
#  |      The metadata kwargs allow functions to be passed in which
#  |      filter traits based on metadata values.  The functions should
#  |      take a single value as an argument and return a boolean.  If
#  |      any function returns False, then the trait is not included in
#  |      the output.  If a metadata key doesn't exist, None will be passed
#  |      to the function.
#  |
#  |  trait_events(name=None) from traitlets.traitlets.MetaHasTraits
#  |      Get a ``dict`` of all the event handlers of this class.
#  |
#  |      Parameters
#  |      ----------
#  |      name : str (default: None)
#  |          The name of a trait of this class. If name is ``None`` then all
#  |          the event handlers of this class will be returned instead.
#  |
#  |      Returns
#  |      -------
#  |      The event handlers associated with a trait name, or all event handlers.
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from traitlets.traitlets.HasTraits:
#  |
#  |  cross_validation_lock
#  |      A contextmanager for running a block with our cross validation lock set
#  |      to True.
#  |
#  |      At the end of the block, the lock's value is restored to its value
#  |      prior to entering the block.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from traitlets.traitlets.HasDescriptors:
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from traitlets.traitlets.HasDescriptors:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
env.show()
# Out:
# Canvas(height=800, width=800)
# RadioButtons(description='Mouse Action:', options=('move', 'zoom', 'select'), value='move')
# IntSlider(value=0, continuous_update=False, description='Frame:', max=9)

# %%
math.sig(-1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-05ece5a59143> in <module>
# ----> 1 math.sig(-1)
#
# AttributeError: module 'math' has no attribute 'sig'

# %%
int(False) * 2 - 1
# Out:
# -1

# %%
import itk

from itkwidgets import view

# %%
help(itk)
# Out:
# Help on package itk:
#
# NAME
#     itk
#
# PACKAGE CONTENTS
#     ITKAnisotropicSmoothingPython
#     ITKAntiAliasPython
#     ITKBiasCorrectionPython
#     ITKBinaryMathematicalMorphologyPython
#     ITKBridgeNumPyPython
#     ITKClassifiersPython
#     ITKColormapPython
#     ITKCommonBasePython
#     ITKCommonPython
#     ITKConnectedComponentsPython
#     ITKConvolutionPython
#     ITKCostFunctionsPython
#     ITKCurvatureFlowPython
#     ITKDeconvolutionPython
#     ITKDisplacementFieldPython
#     ITKDistanceMapPython
#     ITKEigenPython
#     ITKFFTPython
#     ITKFastMarchingBasePython
#     ITKFastMarchingPython
#     ITKFiniteDifferencePython
#     ITKIOBMPPython
#     ITKIOBioRadPython
#     ITKIOBrukerPython
#     ITKIOGDCMPython
#     ITKIOGEPython
#     ITKIOGIPLPython
#     ITKIOHDF5Python
#     ITKIOIPLPython
#     ITKIOImageBaseBasePython
#     ITKIOImageBasePython
#     ITKIOJPEG2000Python
#     ITKIOJPEGPython
#     ITKIOLSMPython
#     ITKIOMINCPython
#     ITKIOMRCPython
#     ITKIOMeshBYUPython
#     ITKIOMeshBasePython
#     ITKIOMeshFreeSurferPython
#     ITKIOMeshGiftiPython
#     ITKIOMeshOBJPython
#     ITKIOMeshOFFPython
#     ITKIOMeshVTKPython
#     ITKIOMetaPython
#     ITKIONIFTIPython
#     ITKIONRRDPython
#     ITKIOPNGPython
#     ITKIORAWPython
#     ITKIOSiemensPython
#     ITKIOSpatialObjectsPython
#     ITKIOStimulatePython
#     ITKIOTIFFPython
#     ITKIOTransformBasePython
#     ITKIOVTKPython
#     ITKImageComparePython
#     ITKImageComposePython
#     ITKImageFeaturePython
#     ITKImageFilterBasePython
#     ITKImageFrequencyPython
#     ITKImageFunctionPython
#     ITKImageFusionPython
#     ITKImageGradientPython
#     ITKImageGridPython
#     ITKImageIntensityPython
#     ITKImageLabelPython
#     ITKImageNoisePython
#     ITKImageSourcesPython
#     ITKImageStatisticsPython
#     ITKLabelMapBasePython
#     ITKLabelMapPython
#     ITKLabelVotingPython
#     ITKLevelSetsPython
#     ITKMathematicalMorphologyPython
#     ITKMeshPython
#     ITKMetricsv4Python
#     ITKNarrowBandBasePython
#     ITKNarrowBandPython
#     ITKOptimizersBasePython
#     ITKOptimizersPython
#     ITKOptimizersv4Python
#     ITKPDEDeformableRegistrationPython
#     ITKPathPython
#     ITKPyBasePython
#     ITKPyUtilsPython
#     ITKQuadEdgeMeshFilteringPython
#     ITKQuadEdgeMeshPython
#     ITKRegionGrowingPython
#     ITKRegistrationCommonPython
#     ITKRegistrationMethodsv4Python
#     ITKSignedDistanceFunctionPython
#     ITKSmoothingPython
#     ITKSpatialObjectsPython
#     ITKStatisticsPython
#     ITKSuperPixelPython
#     ITKTestKernelPython
#     ITKThresholdingPython
#     ITKTransformPython
#     ITKVTKPython
#     ITKVoronoiPython
#     ITKWatershedsPython
#     MeshToPolyDataPython
#     _ITKAnisotropicSmoothingPython
#     _ITKAntiAliasPython
#     _ITKBiasCorrectionPython
#     _ITKBinaryMathematicalMorphologyPython
#     _ITKBridgeNumPyPython
#     _ITKClassifiersPython
#     _ITKColormapPython
#     _ITKCommonPython
#     _ITKConnectedComponentsPython
#     _ITKConvolutionPython
#     _ITKCurvatureFlowPython
#     _ITKDeconvolutionPython
#     _ITKDisplacementFieldPython
#     _ITKDistanceMapPython
#     _ITKEigenPython
#     _ITKFFTPython
#     _ITKFastMarchingPython
#     _ITKFiniteDifferencePython
#     _ITKIOBMPPython
#     _ITKIOBioRadPython
#     _ITKIOBrukerPython
#     _ITKIOGDCMPython
#     _ITKIOGEPython
#     _ITKIOGIPLPython
#     _ITKIOHDF5Python
#     _ITKIOIPLPython
#     _ITKIOImageBasePython
#     _ITKIOJPEG2000Python
#     _ITKIOJPEGPython
#     _ITKIOLSMPython
#     _ITKIOMINCPython
#     _ITKIOMRCPython
#     _ITKIOMeshBYUPython
#     _ITKIOMeshBasePython
#     _ITKIOMeshFreeSurferPython
#     _ITKIOMeshGiftiPython
#     _ITKIOMeshOBJPython
#     _ITKIOMeshOFFPython
#     _ITKIOMeshVTKPython
#     _ITKIOMetaPython
#     _ITKIONIFTIPython
#     _ITKIONRRDPython
#     _ITKIOPNGPython
#     _ITKIORAWPython
#     _ITKIOSiemensPython
#     _ITKIOSpatialObjectsPython
#     _ITKIOStimulatePython
#     _ITKIOTIFFPython
#     _ITKIOTransformBasePython
#     _ITKIOVTKPython
#     _ITKImageComparePython
#     _ITKImageComposePython
#     _ITKImageFeaturePython
#     _ITKImageFilterBasePython
#     _ITKImageFrequencyPython
#     _ITKImageFunctionPython
#     _ITKImageFusionPython
#     _ITKImageGradientPython
#     _ITKImageGridPython
#     _ITKImageIntensityPython
#     _ITKImageLabelPython
#     _ITKImageNoisePython
#     _ITKImageSourcesPython
#     _ITKImageStatisticsPython
#     _ITKLabelMapPython
#     _ITKLabelVotingPython
#     _ITKLevelSetsPython
#     _ITKMathematicalMorphologyPython
#     _ITKMeshPython
#     _ITKMetricsv4Python
#     _ITKNarrowBandPython
#     _ITKOptimizersPython
#     _ITKOptimizersv4Python
#     _ITKPDEDeformableRegistrationPython
#     _ITKPathPython
#     _ITKPyBasePython
#     _ITKPyUtilsPython
#     _ITKQuadEdgeMeshFilteringPython
#     _ITKQuadEdgeMeshPython
#     _ITKRegionGrowingPython
#     _ITKRegistrationCommonPython
#     _ITKRegistrationMethodsv4Python
#     _ITKSignedDistanceFunctionPython
#     _ITKSmoothingPython
#     _ITKSpatialObjectsPython
#     _ITKStatisticsPython
#     _ITKSuperPixelPython
#     _ITKTestKernelPython
#     _ITKThresholdingPython
#     _ITKTransformPython
#     _ITKVTKPython
#     _ITKVoronoiPython
#     _ITKWatershedsPython
#     _MeshToPolyDataPython
#     itkAbsImageFilterPython
#     itkAbsoluteValueDifferenceImageFilterPython
#     itkAccumulateImageFilterPython
#     itkAcosImageFilterPython
#     itkAdaptiveHistogramEqualizationImageFilterPython
#     itkAddImageFilterPython
#     itkAdditiveGaussianNoiseImageFilterPython
#     itkAffineTransformPython
#     itkAggregateLabelMapFilterPython
#     itkAndImageFilterPython
#     itkAnisotropicDiffusionImageFilterPython
#     itkAnisotropicFourthOrderLevelSetImageFilterPython
#     itkAnnulusOperatorPython
#     itkAntiAliasBinaryImageFilterPython
#     itkApproximateSignedDistanceMapImageFilterPython
#     itkArray2DPython
#     itkArrayPython
#     itkArrowSpatialObjectPython
#     itkAsinImageFilterPython
#     itkAtan2ImageFilterPython
#     itkAtanImageFilterPython
#     itkAutoCropLabelMapFilterPython
#     itkAzimuthElevationToCartesianTransformPython
#     itkBMPImageIOPython
#     itkBSplineBaseTransformPython
#     itkBSplineDecompositionImageFilterPython
#     itkBSplineDownsampleImageFilterPython
#     itkBSplineExponentialDiffeomorphicTransformPython
#     itkBSplineInterpolateImageFunctionPython
#     itkBSplineInterpolationWeightFunctionPython
#     itkBSplineResampleImageFunctionPython
#     itkBSplineSmoothingOnUpdateDisplacementFieldTransformPython
#     itkBSplineTransformInitializerPython
#     itkBSplineTransformPython
#     itkBSplineUpsampleImageFilterPython
#     itkBYUMeshIOPython
#     itkBackwardDifferenceOperatorPython
#     itkBayesianClassifierImageFilterPython
#     itkBayesianClassifierInitializationImageFilterPython
#     itkBilateralImageFilterPython
#     itkBinShrinkImageFilterPython
#     itkBinaryClosingByReconstructionImageFilterPython
#     itkBinaryContourImageFilterPython
#     itkBinaryDilateImageFilterPython
#     itkBinaryErodeImageFilterPython
#     itkBinaryFillholeImageFilterPython
#     itkBinaryGeneratorImageFilterPython
#     itkBinaryGrindPeakImageFilterPython
#     itkBinaryImageToLabelMapFilterPython
#     itkBinaryImageToShapeLabelMapFilterPython
#     itkBinaryImageToStatisticsLabelMapFilterPython
#     itkBinaryMagnitudeImageFilterPython
#     itkBinaryMask3DMeshSourcePython
#     itkBinaryMaskToNarrowBandPointSetFilterPython
#     itkBinaryMedianImageFilterPython
#     itkBinaryMinMaxCurvatureFlowImageFilterPython
#     itkBinaryMorphologicalClosingImageFilterPython
#     itkBinaryMorphologicalOpeningImageFilterPython
#     itkBinaryNotImageFilterPython
#     itkBinaryOpeningByReconstructionImageFilterPython
#     itkBinaryProjectionImageFilterPython
#     itkBinaryPruningImageFilterPython
#     itkBinaryReconstructionByDilationImageFilterPython
#     itkBinaryReconstructionByErosionImageFilterPython
#     itkBinaryShapeKeepNObjectsImageFilterPython
#     itkBinaryShapeOpeningImageFilterPython
#     itkBinaryStatisticsKeepNObjectsImageFilterPython
#     itkBinaryStatisticsOpeningImageFilterPython
#     itkBinaryThinningImageFilterPython
#     itkBinaryThresholdImageFilterPython
#     itkBinaryThresholdProjectionImageFilterPython
#     itkBinomialBlurImageFilterPython
#     itkBioRadImageIOPython
#     itkBlackTopHatImageFilterPython
#     itkBlobSpatialObjectPython
#     itkBlockMatchingImageFilterPython
#     itkBorderQuadEdgeMeshFilterPython
#     itkBoundedReciprocalImageFilterPython
#     itkBoundingBoxPython
#     itkBoxImageFilterPython
#     itkBoxSpatialObjectPython
#     itkBruker2dseqImageIOPython
#     itkCannyEdgeDetectionImageFilterPython
#     itkCannySegmentationLevelSetImageFilterPython
#     itkCastImageFilterPython
#     itkCastSpatialObjectFilterPython
#     itkCenteredAffineTransformPython
#     itkCenteredEuler3DTransformPython
#     itkCenteredRigid2DTransformPython
#     itkCenteredSimilarity2DTransformPython
#     itkCenteredTransformInitializerPython
#     itkCenteredVersorTransformInitializerPython
#     itkChangeInformationImageFilterPython
#     itkChangeLabelImageFilterPython
#     itkChangeLabelLabelMapFilterPython
#     itkChangeRegionLabelMapFilterPython
#     itkCheckerBoardImageFilterPython
#     itkClampImageFilterPython
#     itkCleanQuadEdgeMeshFilterPython
#     itkClosingByReconstructionImageFilterPython
#     itkCollidingFrontsImageFilterPython
#     itkColormapFunctionPython
#     itkComparisonImageFilterPython
#     itkComplexToComplexFFTImageFilterPython
#     itkComplexToImaginaryImageFilterPython
#     itkComplexToModulusImageFilterPython
#     itkComplexToPhaseImageFilterPython
#     itkComplexToRealImageFilterPython
#     itkComposeImageFilterPython
#     itkComposeScaleSkewVersor3DTransformPython
#     itkCompositeTransformPython
#     itkConfidenceConnectedImageFilterPython
#     itkConnectedComponentImageFilterPython
#     itkConnectedRegionsMeshFilterPython
#     itkConnectedThresholdImageFilterPython
#     itkConstantPadImageFilterPython
#     itkConstantVelocityFieldTransformPython
#     itkConstrainedValueAdditionImageFilterPython
#     itkConstrainedValueDifferenceImageFilterPython
#     itkContinuousIndexPython
#     itkContourDirectedMeanDistanceImageFilterPython
#     itkContourExtractor2DImageFilterPython
#     itkContourMeanDistanceImageFilterPython
#     itkContourSpatialObjectPointPython
#     itkContourSpatialObjectPython
#     itkConvolutionImageFilterBasePython
#     itkConvolutionImageFilterPython
#     itkCorrelationImageToImageMetricv4Python
#     itkCosImageFilterPython
#     itkCostFunctionPython
#     itkCovariantVectorPython
#     itkCropImageFilterPython
#     itkCropLabelMapFilterPython
#     itkCurvatureAnisotropicDiffusionImageFilterPython
#     itkCurvatureFlowImageFilterPython
#     itkCurvesLevelSetImageFilterPython
#     itkCustomColormapFunctionPython
#     itkCyclicShiftImageFilterPython
#     itkDTITubeSpatialObjectPointPython
#     itkDTITubeSpatialObjectPython
#     itkDanielssonDistanceMapImageFilterPython
#     itkDefaultDynamicMeshTraitsPython
#     itkDefaultStaticMeshTraitsPython
#     itkDelaunayConformingQuadEdgeMeshFilterPython
#     itkDemonsImageToImageMetricv4Python
#     itkDemonsRegistrationFilterPython
#     itkDenseFiniteDifferenceImageFilterPython
#     itkDerivativeImageFilterPython
#     itkDerivativeOperatorPython
#     itkDifferenceOfGaussiansGradientImageFilterPython
#     itkDiffusionTensor3DPython
#     itkDilateObjectMorphologyImageFilterPython
#     itkDirectedHausdorffDistanceImageFilterPython
#     itkDiscreteCurvatureQuadEdgeMeshFilterPython
#     itkDiscreteCurvatureTensorQuadEdgeMeshFilterPython
#     itkDiscreteGaussianCurvatureQuadEdgeMeshFilterPython
#     itkDiscreteGaussianDerivativeImageFilterPython
#     itkDiscreteGaussianImageFilterPython
#     itkDiscreteMaximumCurvatureQuadEdgeMeshFilterPython
#     itkDiscreteMeanCurvatureQuadEdgeMeshFilterPython
#     itkDiscreteMinimumCurvatureQuadEdgeMeshFilterPython
#     itkDiscretePrincipalCurvaturesQuadEdgeMeshFilterPython
#     itkDisplacementFieldJacobianDeterminantFilterPython
#     itkDisplacementFieldTransformPython
#     itkDistanceMetricPython
#     itkDivideImageFilterPython
#     itkDoubleThresholdImageFilterPython
#     itkEdgePotentialImageFilterPython
#     itkEigenAnalysis2DImageFilterPython
#     itkElasticBodyReciprocalSplineKernelTransformPython
#     itkElasticBodySplineKernelTransformPython
#     itkEllipseSpatialObjectPython
#     itkErodeObjectMorphologyImageFilterPython
#     itkEuclideanDistanceMetricPython
#     itkEuclideanDistancePointSetToPointSetMetricPython
#     itkEuler2DTransformPython
#     itkEuler3DTransformPython
#     itkExhaustiveOptimizerv4Python
#     itkExpImageFilterPython
#     itkExpNegativeImageFilterPython
#     itkExpandImageFilterPython
#     itkExpectationBasedPointSetToPointSetMetricv4Python
#     itkExtractImageFilterPython
#     itkExtrapolateImageFunctionPython
#     itkFFTConvolutionImageFilterPython
#     itkFFTNormalizedCorrelationImageFilterPython
#     itkFFTPadImageFilterPython
#     itkFFTShiftImageFilterPython
#     itkFFTWComplexToComplexFFTImageFilterPython
#     itkFFTWForwardFFTImageFilterPython
#     itkFFTWGlobalConfigurationPython
#     itkFFTWHalfHermitianToRealInverseFFTImageFilterPython
#     itkFFTWInverseFFTImageFilterPython
#     itkFFTWRealToHalfHermitianForwardFFTImageFilterPython
#     itkFastChamferDistanceImageFilterPython
#     itkFastMarchingExtensionImageFilterPython
#     itkFastMarchingImageFilterBasePython
#     itkFastMarchingImageFilterPython
#     itkFastMarchingImageToNodePairContainerAdaptorPython
#     itkFastMarchingReachedTargetNodesStoppingCriterionPython
#     itkFastMarchingStoppingCriterionBasePython
#     itkFastMarchingThresholdStoppingCriterionPython
#     itkFastMarchingUpwindGradientImageFilterBasePython
#     itkFastMarchingUpwindGradientImageFilterPython
#     itkFiniteDifferenceFunctionPython
#     itkFiniteDifferenceImageFilterPython
#     itkFixedArrayPython
#     itkFixedCenterOfRotationAffineTransformPython
#     itkFlatStructuringElementPython
#     itkFlipImageFilterPython
#     itkFloatingPointExceptionsPython
#     itkForwardDifferenceOperatorPython
#     itkForwardFFTImageFilterPython
#     itkFreeSurferAsciiMeshIOPython
#     itkFreeSurferBinaryMeshIOPython
#     itkFrequencyBandImageFilterPython
#     itkFullToHalfHermitianImageFilterPython
#     itkFunctionBasePython
#     itkGDCMImageIOPython
#     itkGE4ImageIOPython
#     itkGE5ImageIOPython
#     itkGEAdwImageIOPython
#     itkGaborImageSourcePython
#     itkGaussianDerivativeOperatorPython
#     itkGaussianExponentialDiffeomorphicTransformPython
#     itkGaussianImageSourcePython
#     itkGaussianInterpolateImageFunctionPython
#     itkGaussianOperatorPython
#     itkGaussianSmoothingOnUpdateDisplacementFieldTransformPython
#     itkGaussianSmoothingOnUpdateTimeVaryingVelocityFieldTransformPython
#     itkGaussianSpatialObjectPython
#     itkGenerateImageSourcePython
#     itkGeodesicActiveContourLevelSetImageFilterPython
#     itkGeodesicActiveContourShapePriorLevelSetImageFilterPython
#     itkGeometricalQuadEdgePython
#     itkGiftiMeshIOPython
#     itkGiplImageIOPython
#     itkGradientAnisotropicDiffusionImageFilterPython
#     itkGradientDescentOptimizerBasev4Python
#     itkGradientDescentOptimizerv4Python
#     itkGradientImageFilterPython
#     itkGradientMagnitudeImageFilterPython
#     itkGradientMagnitudeRecursiveGaussianImageFilterPython
#     itkGradientRecursiveGaussianImageFilterPython
#     itkGradientVectorFlowImageFilterPython
#     itkGrayscaleConnectedClosingImageFilterPython
#     itkGrayscaleConnectedOpeningImageFilterPython
#     itkGrayscaleDilateImageFilterPython
#     itkGrayscaleErodeImageFilterPython
#     itkGrayscaleFillholeImageFilterPython
#     itkGrayscaleFunctionDilateImageFilterPython
#     itkGrayscaleFunctionErodeImageFilterPython
#     itkGrayscaleGeodesicDilateImageFilterPython
#     itkGrayscaleGeodesicErodeImageFilterPython
#     itkGrayscaleGrindPeakImageFilterPython
#     itkGrayscaleMorphologicalClosingImageFilterPython
#     itkGrayscaleMorphologicalOpeningImageFilterPython
#     itkGridImageSourcePython
#     itkGroupSpatialObjectPython
#     itkHConcaveImageFilterPython
#     itkHConvexImageFilterPython
#     itkHDF5ImageIOPython
#     itkHMaximaImageFilterPython
#     itkHMinimaImageFilterPython
#     itkHalfHermitianToRealInverseFFTImageFilterPython
#     itkHalfToFullHermitianImageFilterPython
#     itkHardConnectedComponentImageFilterPython
#     itkHausdorffDistanceImageFilterPython
#     itkHessian3DToVesselnessMeasureImageFilterPython
#     itkHessianRecursiveGaussianImageFilterPython
#     itkHessianToObjectnessMeasureImageFilterPython
#     itkHistogramMatchingImageFilterPython
#     itkHistogramPython
#     itkHistogramThresholdCalculatorPython
#     itkHistogramThresholdImageFilterPython
#     itkHistogramToEntropyImageFilterPython
#     itkHistogramToIntensityImageFilterPython
#     itkHistogramToLogProbabilityImageFilterPython
#     itkHistogramToProbabilityImageFilterPython
#     itkHistogramToRunLengthFeaturesFilterPython
#     itkHistogramToTextureFeaturesFilterPython
#     itkHoughTransform2DCirclesImageFilterPython
#     itkHoughTransform2DLinesImageFilterPython
#     itkHuangThresholdCalculatorPython
#     itkHuangThresholdImageFilterPython
#     itkIPLCommonImageIOPython
#     itkIdentityTransformPython
#     itkImageBoundaryConditionPython
#     itkImageDuplicatorPython
#     itkImageFileReaderPython
#     itkImageFileWriterPython
#     itkImageFunctionBasePython
#     itkImageKernelOperatorPython
#     itkImageMaskSpatialObjectPython
#     itkImageMomentsCalculatorPython
#     itkImagePCAShapeModelEstimatorPython
#     itkImagePython
#     itkImageRegionPython
#     itkImageRegistrationMethodPython
#     itkImageRegistrationMethodv4Python
#     itkImageSeriesReaderPython
#     itkImageSeriesWriterPython
#     itkImageShapeModelEstimatorBasePython
#     itkImageSinkPython
#     itkImageSourceCommonPython
#     itkImageSourcePython
#     itkImageSpatialObjectPython
#     itkImageToHistogramFilterPython
#     itkImageToImageFilterAPython
#     itkImageToImageFilterBPython
#     itkImageToImageFilterCommonPython
#     itkImageToImageMetricPython
#     itkImageToImageMetricv4Python
#     itkImageToMeshFilterPython
#     itkImageToPathFilterPython
#     itkImageToPointSetFilterPython
#     itkImportImageFilterPython
#     itkInPlaceImageFilterAPython
#     itkInPlaceImageFilterBPython
#     itkInPlaceLabelMapFilterPython
#     itkIndexPython
#     itkIntensityWindowingImageFilterPython
#     itkIntermodesThresholdCalculatorPython
#     itkIntermodesThresholdImageFilterPython
#     itkInterpolateImageFilterPython
#     itkInterpolateImageFunctionPython
#     itkInverseDeconvolutionImageFilterPython
#     itkInverseFFTImageFilterPython
#     itkInvertIntensityImageFilterPython
#     itkIsoContourDistanceImageFilterPython
#     itkIsoDataThresholdCalculatorPython
#     itkIsoDataThresholdImageFilterPython
#     itkIsolatedConnectedImageFilterPython
#     itkIsolatedWatershedImageFilterPython
#     itkIsotropicFourthOrderLevelSetImageFilterPython
#     itkIterativeDeconvolutionImageFilterPython
#     itkJPEG2000ImageIOPython
#     itkJPEGImageIOPython
#     itkJensenHavrdaCharvatTsallisPointSetToPointSetMetricv4Python
#     itkJoinSeriesImageFilterPython
#     itkJointHistogramMutualInformationImageToImageMetricv4Python
#     itkKappaSigmaThresholdImageFilterPython
#     itkKdTreeBasedKmeansEstimatorPython
#     itkKdTreeGeneratorPython
#     itkKdTreePython
#     itkKernelFunctionBasePython
#     itkKernelTransformPython
#     itkKittlerIllingworthThresholdCalculatorPython
#     itkKittlerIllingworthThresholdImageFilterPython
#     itkLSMImageIOPython
#     itkLabelContourImageFilterPython
#     itkLabelImageGaussianInterpolateImageFunctionPython
#     itkLabelImageToLabelMapFilterPython
#     itkLabelImageToShapeLabelMapFilterPython
#     itkLabelImageToStatisticsLabelMapFilterPython
#     itkLabelMapContourOverlayImageFilterPython
#     itkLabelMapFilterPython
#     itkLabelMapMaskImageFilterPython
#     itkLabelMapOverlayImageFilterPython
#     itkLabelMapToBinaryImageFilterPython
#     itkLabelMapToLabelImageFilterPython
#     itkLabelMapToRGBImageFilterPython
#     itkLabelObjectLinePython
#     itkLabelObjectPython
#     itkLabelOverlayImageFilterPython
#     itkLabelSelectionLabelMapFilterPython
#     itkLabelShapeKeepNObjectsImageFilterPython
#     itkLabelShapeOpeningImageFilterPython
#     itkLabelStatisticsImageFilterPython
#     itkLabelStatisticsKeepNObjectsImageFilterPython
#     itkLabelStatisticsOpeningImageFilterPython
#     itkLabelToRGBImageFilterPython
#     itkLabelUniqueLabelMapFilterPython
#     itkLabelVotingImageFilterPython
#     itkLabeledPointSetToPointSetMetricv4Python
#     itkLandmarkBasedTransformInitializerPython
#     itkLandmarkSpatialObjectPython
#     itkLandweberDeconvolutionImageFilterPython
#     itkLaplacianImageFilterPython
#     itkLaplacianOperatorPython
#     itkLaplacianRecursiveGaussianImageFilterPython
#     itkLaplacianSegmentationLevelSetImageFilterPython
#     itkLaplacianSharpeningImageFilterPython
#     itkLevelSetFunctionPython
#     itkLevelSetMotionRegistrationFilterPython
#     itkLevelSetNodePython
#     itkLiThresholdCalculatorPython
#     itkLiThresholdImageFilterPython
#     itkLineSpatialObjectPointPython
#     itkLineSpatialObjectPython
#     itkLinearInterpolateImageFunctionPython
#     itkListSamplePython
#     itkLog10ImageFilterPython
#     itkLogImageFilterPython
#     itkMINCImageIOPython
#     itkMRCImageIOPython
#     itkMagnitudeAndPhaseToComplexImageFilterPython
#     itkMapContainerPython
#     itkMaskFeaturePointSelectionFilterPython
#     itkMaskImageFilterPython
#     itkMaskNegatedImageFilterPython
#     itkMaskedFFTNormalizedCorrelationImageFilterPython
#     itkMaskedImageToHistogramFilterPython
#     itkMatrixCoefficientsPython
#     itkMatrixOffsetTransformBasePython
#     itkMatrixPython
#     itkMattesMutualInformationImageToImageMetricPython
#     itkMattesMutualInformationImageToImageMetricv4Python
#     itkMaximumEntropyThresholdCalculatorPython
#     itkMaximumEntropyThresholdImageFilterPython
#     itkMaximumImageFilterPython
#     itkMaximumProjectionImageFilterPython
#     itkMeanImageFilterPython
#     itkMeanProjectionImageFilterPython
#     itkMeanReciprocalSquareDifferenceImageToImageMetricPython
#     itkMeanSquaresImageToImageMetricPython
#     itkMeanSquaresImageToImageMetricv4Python
#     itkMedianImageFilterPython
#     itkMedianProjectionImageFilterPython
#     itkMembershipFunctionBasePython
#     itkMergeLabelMapFilterPython
#     itkMeshBasePython
#     itkMeshFileReaderPython
#     itkMeshFileWriterPython
#     itkMeshIOBasePython
#     itkMeshIOFactoryPython
#     itkMeshSourcePython
#     itkMeshToMeshFilterPython
#     itkMeshToPolyDataFilterPython
#     itkMetaConverterBasePython
#     itkMetaDataObjectPython
#     itkMetaImageIOPython
#     itkMinMaxCurvatureFlowImageFilterPython
#     itkMinimumImageFilterPython
#     itkMinimumMaximumImageCalculatorPython
#     itkMinimumMaximumImageFilterPython
#     itkMinimumProjectionImageFilterPython
#     itkMirrorPadImageFilterPython
#     itkModulusImageFilterPython
#     itkMomentsThresholdCalculatorPython
#     itkMomentsThresholdImageFilterPython
#     itkMorphologicalGradientImageFilterPython
#     itkMorphologicalWatershedFromMarkersImageFilterPython
#     itkMorphologicalWatershedImageFilterPython
#     itkMultiResolutionImageRegistrationMethodPython
#     itkMultiResolutionPDEDeformableRegistrationPython
#     itkMultiResolutionPyramidImageFilterPython
#     itkMultiScaleHessianBasedMeasureImageFilterPython
#     itkMultiTransformPython
#     itkMultiplyImageFilterPython
#     itkMutualInformationImageToImageMetricPython
#     itkN4BiasFieldCorrectionImageFilterPython
#     itkNarrowBandCurvesLevelSetImageFilterPython
#     itkNarrowBandImageFilterBasePython
#     itkNarrowBandLevelSetImageFilterPython
#     itkNarrowBandThresholdSegmentationLevelSetImageFilterPython
#     itkNaryAddImageFilterPython
#     itkNaryMaximumImageFilterPython
#     itkNearestNeighborInterpolateImageFunctionPython
#     itkNeighborhoodConnectedImageFilterPython
#     itkNeighborhoodOperatorImageFilterPython
#     itkNeighborhoodOperatorPython
#     itkNeighborhoodPython
#     itkNiftiImageIOPython
#     itkNodePairPython
#     itkNoiseBaseImageFilterPython
#     itkNoiseImageFilterPython
#     itkNormalVariateGeneratorPython
#     itkNormalizeImageFilterPython
#     itkNormalizeToConstantImageFilterPython
#     itkNormalizedCorrelationImageToImageMetricPython
#     itkNotImageFilterPython
#     itkNrrdImageIOPython
#     itkNumericTraitsPython
#     itkOBJMeshIOPython
#     itkOFFMeshIOPython
#     itkObjectByObjectLabelMapFilterPython
#     itkObjectToObjectMetricBasePython
#     itkObjectToObjectMetricPython
#     itkObjectToObjectOptimizerBasePython
#     itkOffsetPython
#     itkOpeningByReconstructionImageFilterPython
#     itkOptimizerParameterScalesEstimatorPython
#     itkOptimizerParametersPython
#     itkOrImageFilterPython
#     itkOrientImageFilterPython
#     itkOtsuMultipleThresholdsImageFilterPython
#     itkOtsuThresholdCalculatorPython
#     itkOtsuThresholdImageFilterPython
#     itkPCAShapeSignedDistanceFunctionPython
#     itkPDEDeformableRegistrationFilterPython
#     itkPDEDeformableRegistrationFunctionPython
#     itkPNGImageIOPython
#     itkPadImageFilterBasePython
#     itkPadImageFilterPython
#     itkPadLabelMapFilterPython
#     itkParallelSparseFieldLevelSetImageFilterPython
#     itkParametricImageSourcePython
#     itkParametricPathPython
#     itkPasteImageFilterPython
#     itkPathBasePython
#     itkPathSourcePython
#     itkPathToImageFilterPython
#     itkPermuteAxesImageFilterPython
#     itkPhysicalPointImageSourcePython
#     itkPipelineMonitorImageFilterPython
#     itkPointBasedSpatialObjectPython
#     itkPointPython
#     itkPointSetPython
#     itkPolyDataPython
#     itkPolyLineParametricPathPython
#     itkPolygonSpatialObjectPython
#     itkPowImageFilterPython
#     itkProjectedLandweberDeconvolutionImageFilterPython
#     itkPyBufferPython
#     itkPyCommandPython
#     itkPyImageFilterPython
#     itkPyVectorContainerPython
#     itkQuadEdgeCellTraitsInfoPython
#     itkQuadEdgeMeshBasePython
#     itkQuadEdgeMeshLineCellPython
#     itkQuadEdgeMeshPointPython
#     itkQuadEdgeMeshToQuadEdgeMeshFilterPython
#     itkQuadEdgeMeshTraitsPython
#     itkQuadEdgePython
#     itkQuasiNewtonOptimizerv4Python
#     itkQuaternionRigidTransformPython
#     itkRGBAPixelPython
#     itkRGBPixelPython
#     itkRGBToLuminanceImageFilterPython
#     itkRandomImageSourcePython
#     itkRawImageIOPython
#     itkRayCastInterpolateImageFunctionPython
#     itkRealToHalfHermitianForwardFFTImageFilterPython
#     itkReconstructionByDilationImageFilterPython
#     itkReconstructionByErosionImageFilterPython
#     itkRecursiveGaussianImageFilterPython
#     itkRecursiveMultiResolutionPyramidImageFilterPython
#     itkRecursiveSeparableImageFilterPython
#     itkRegionFromReferenceLabelMapFilterPython
#     itkRegionOfInterestImageFilterPython
#     itkRegionalMaximaImageFilterPython
#     itkRegionalMinimaImageFilterPython
#     itkRegularStepGradientDescentOptimizerv4Python
#     itkReinitializeLevelSetImageFilterPython
#     itkRelabelComponentImageFilterPython
#     itkRelabelLabelMapFilterPython
#     itkRenyiEntropyThresholdCalculatorPython
#     itkRenyiEntropyThresholdImageFilterPython
#     itkResampleImageFilterPython
#     itkRescaleIntensityImageFilterPython
#     itkRichardsonLucyDeconvolutionImageFilterPython
#     itkRigid2DTransformPython
#     itkRigid3DPerspectiveTransformPython
#     itkRigid3DTransformPython
#     itkRoundImageFilterPython
#     itkSLICImageFilterPython
#     itkSTAPLEImageFilterPython
#     itkSaltAndPepperNoiseImageFilterPython
#     itkSamplePython
#     itkScalableAffineTransformPython
#     itkScalarConnectedComponentImageFilterPython
#     itkScalarImageKmeansImageFilterPython
#     itkScalarImageToCooccurrenceMatrixFilterPython
#     itkScalarImageToHistogramGeneratorPython
#     itkScalarImageToRunLengthFeaturesFilterPython
#     itkScalarImageToRunLengthMatrixFilterPython
#     itkScalarImageToTextureFeaturesFilterPython
#     itkScalarToRGBColormapImageFilterPython
#     itkScaleLogarithmicTransformPython
#     itkScaleSkewVersor3DTransformPython
#     itkScaleTransformPython
#     itkScaleVersor3DTransformPython
#     itkScanlineFilterCommonPython
#     itkSegmentationLevelSetFunctionPython
#     itkSegmentationLevelSetImageFilterPython
#     itkShanbhagThresholdCalculatorPython
#     itkShanbhagThresholdImageFilterPython
#     itkShapeDetectionLevelSetImageFilterPython
#     itkShapeKeepNObjectsLabelMapFilterPython
#     itkShapeLabelMapFilterPython
#     itkShapeLabelObjectPython
#     itkShapeOpeningLabelMapFilterPython
#     itkShapePositionLabelMapFilterPython
#     itkShapePriorMAPCostFunctionBasePython
#     itkShapePriorMAPCostFunctionPython
#     itkShapePriorSegmentationLevelSetImageFilterPython
#     itkShapeRelabelImageFilterPython
#     itkShapeRelabelLabelMapFilterPython
#     itkShapeSignedDistanceFunctionPython
#     itkShapeUniqueLabelMapFilterPython
#     itkShiftScaleImageFilterPython
#     itkShiftScaleLabelMapFilterPython
#     itkShotNoiseImageFilterPython
#     itkShrinkImageFilterPython
#     itkSiemensVisionImageIOPython
#     itkSigmoidImageFilterPython
#     itkSignedDanielssonDistanceMapImageFilterPython
#     itkSignedMaurerDistanceMapImageFilterPython
#     itkSimilarity2DTransformPython
#     itkSimilarity3DTransformPython
#     itkSimilarityIndexImageFilterPython
#     itkSimpleContourExtractorImageFilterPython
#     itkSimpleDataObjectDecoratorPython
#     itkSinImageFilterPython
#     itkSingleValuedCostFunctionv4Python
#     itkSizePython
#     itkSliceBySliceImageFilterPython
#     itkSmoothingQuadEdgeMeshFilterPython
#     itkSmoothingRecursiveGaussianImageFilterPython
#     itkSobelEdgeDetectionImageFilterPython
#     itkSobelOperatorPython
#     itkSparseFieldFourthOrderLevelSetImageFilterPython
#     itkSparseFieldLevelSetImageFilterPython
#     itkSpatialFunctionPython
#     itkSpatialObjectBasePython
#     itkSpatialObjectPointPython
#     itkSpatialObjectPropertyPython
#     itkSpatialObjectReaderPython
#     itkSpatialObjectToImageFilterPython
#     itkSpatialObjectWriterPython
#     itkSpatialOrientationPython
#     itkSpeckleNoiseImageFilterPython
#     itkSqrtImageFilterPython
#     itkSquareImageFilterPython
#     itkSquaredDifferenceImageFilterPython
#     itkStandardDeviationProjectionImageFilterPython
#     itkStatisticsImageFilterPython
#     itkStatisticsKeepNObjectsLabelMapFilterPython
#     itkStatisticsLabelMapFilterPython
#     itkStatisticsLabelObjectPython
#     itkStatisticsOpeningLabelMapFilterPython
#     itkStatisticsPositionLabelMapFilterPython
#     itkStatisticsRelabelImageFilterPython
#     itkStatisticsRelabelLabelMapFilterPython
#     itkStatisticsUniqueLabelMapFilterPython
#     itkStimulateImageIOPython
#     itkStreamingImageFilterPython
#     itkSubtractImageFilterPython
#     itkSumProjectionImageFilterPython
#     itkSurfaceSpatialObjectPointPython
#     itkSurfaceSpatialObjectPython
#     itkSymmetricEigenAnalysisImageFilterPython
#     itkSymmetricForcesDemonsRegistrationFilterPython
#     itkSymmetricSecondRankTensorPython
#     itkTIFFImageIOPython
#     itkTanImageFilterPython
#     itkTernaryAddImageFilterPython
#     itkTernaryMagnitudeImageFilterPython
#     itkTernaryMagnitudeSquaredImageFilterPython
#     itkThinPlateR2LogRSplineKernelTransformPython
#     itkThinPlateSplineKernelTransformPython
#     itkThresholdImageFilterPython
#     itkThresholdLabelerImageFilterPython
#     itkThresholdMaximumConnectedComponentsImageFilterPython
#     itkThresholdSegmentationLevelSetImageFilterPython
#     itkTikhonovDeconvolutionImageFilterPython
#     itkTileImageFilterPython
#     itkTimeVaryingVelocityFieldTransformPython
#     itkTobogganImageFilterPython
#     itkTransformBasePython
#     itkTransformFileReaderPython
#     itkTransformFileWriterPython
#     itkTransformIOBaseTemplatePython
#     itkTransformMeshFilterPython
#     itkTransformParametersAdaptorBasePython
#     itkTranslationTransformPython
#     itkTriangleHelperPython
#     itkTriangleMeshToBinaryImageFilterPython
#     itkTriangleThresholdCalculatorPython
#     itkTriangleThresholdImageFilterPython
#     itkTubeSpatialObjectPointPython
#     itkTubeSpatialObjectPython
#     itkUnaryFrequencyDomainFilterPython
#     itkUnaryGeneratorImageFilterPython
#     itkUnsharpMaskImageFilterPython
#     itkUnsharpMaskLevelSetImageFilterPython
#     itkVTKImageExportPython
#     itkVTKImageIOPython
#     itkVTKImageImportPython
#     itkVTKPolyDataMeshIOPython
#     itkVTKPolyDataReaderPython
#     itkVTKPolyDataWriterPython
#     itkValuedRegionalMaximaImageFilterPython
#     itkValuedRegionalMinimaImageFilterPython
#     itkVariableLengthVectorPython
#     itkVariableSizeMatrixPython
#     itkVectorConfidenceConnectedImageFilterPython
#     itkVectorConnectedComponentImageFilterPython
#     itkVectorContainerPython
#     itkVectorCurvatureAnisotropicDiffusionImageFilterPython
#     itkVectorGradientAnisotropicDiffusionImageFilterPython
#     itkVectorGradientMagnitudeImageFilterPython
#     itkVectorImagePython
#     itkVectorIndexSelectionCastImageFilterPython
#     itkVectorMagnitudeImageFilterPython
#     itkVectorPython
#     itkVectorRescaleIntensityImageFilterPython
#     itkVectorThresholdSegmentationLevelSetImageFilterPython
#     itkVelocityFieldTransformPython
#     itkVersorPython
#     itkVersorRigid3DTransformPython
#     itkVersorTransformPython
#     itkVnlComplexToComplexFFTImageFilterPython
#     itkVnlForwardFFTImageFilterPython
#     itkVnlHalfHermitianToRealInverseFFTImageFilterPython
#     itkVnlInverseFFTImageFilterPython
#     itkVnlRealToHalfHermitianForwardFFTImageFilterPython
#     itkVolumeSplineKernelTransformPython
#     itkVoronoiSegmentationImageFilterPython
#     itkVotingBinaryHoleFillingImageFilterPython
#     itkVotingBinaryImageFilterPython
#     itkVotingBinaryIterativeHoleFillingImageFilterPython
#     itkWarpImageFilterPython
#     itkWatershedImageFilterPython
#     itkWeightedAddImageFilterPython
#     itkWeightedCentroidKdTreeGeneratorPython
#     itkWhiteTopHatImageFilterPython
#     itkWienerDeconvolutionImageFilterPython
#     itkWindowedSincInterpolateImageFunctionPython
#     itkWrapPadImageFilterPython
#     itkXorImageFilterPython
#     itkYenThresholdCalculatorPython
#     itkYenThresholdImageFilterPython
#     itkZeroCrossingBasedEdgeDetectionImageFilterPython
#     itkZeroCrossingImageFilterPython
#     itkZeroFluxNeumannPadImageFilterPython
#     pyBasePython
#     stdcomplexPython
#     vnl_c_vectorPython
#     vnl_cost_functionPython
#     vnl_diag_matrixPython
#     vnl_file_matrixPython
#     vnl_file_vectorPython
#     vnl_fortran_copyPython
#     vnl_least_squares_functionPython
#     vnl_matrixPython
#     vnl_matrix_fixedPython
#     vnl_matrix_fixed_refPython
#     vnl_matrix_refPython
#     vnl_unary_functionPython
#     vnl_vectorPython
#     vnl_vector_refPython
#
# FUNCTIONS
#     endl(...)
#         endl(ostream value) -> ostream
#
#     ends(...)
#         ends(ostream value) -> ostream
#
#     flush(...)
#         flush(ostream value) -> ostream
#
#     ios_base_sync_with_stdio(...)
#         ios_base_sync_with_stdio(bool __sync=True) -> bool
#
#     ios_base_xalloc(...)
#         ios_base_xalloc() -> int
#
#     stdnumeric_limitsB_denorm_min(...)
#         stdnumeric_limitsB_denorm_min() -> bool
#
#     stdnumeric_limitsB_epsilon(...)
#         stdnumeric_limitsB_epsilon() -> bool
#
#     stdnumeric_limitsB_infinity(...)
#         stdnumeric_limitsB_infinity() -> bool
#
#     stdnumeric_limitsB_lowest(...)
#         stdnumeric_limitsB_lowest() -> bool
#
#     stdnumeric_limitsB_max(...)
#         stdnumeric_limitsB_max() -> bool
#
#     stdnumeric_limitsB_min(...)
#         stdnumeric_limitsB_min() -> bool
#
#     stdnumeric_limitsB_quiet_NaN(...)
#         stdnumeric_limitsB_quiet_NaN() -> bool
#
#     stdnumeric_limitsB_round_error(...)
#         stdnumeric_limitsB_round_error() -> bool
#
#     stdnumeric_limitsB_signaling_NaN(...)
#         stdnumeric_limitsB_signaling_NaN() -> bool
#
#     stdnumeric_limitsD_denorm_min(...)
#         stdnumeric_limitsD_denorm_min() -> double
#
#     stdnumeric_limitsD_epsilon(...)
#         stdnumeric_limitsD_epsilon() -> double
#
#     stdnumeric_limitsD_infinity(...)
#         stdnumeric_limitsD_infinity() -> double
#
#     stdnumeric_limitsD_lowest(...)
#         stdnumeric_limitsD_lowest() -> double
#
#     stdnumeric_limitsD_max(...)
#         stdnumeric_limitsD_max() -> double
#
#     stdnumeric_limitsD_min(...)
#         stdnumeric_limitsD_min() -> double
#
#     stdnumeric_limitsD_quiet_NaN(...)
#         stdnumeric_limitsD_quiet_NaN() -> double
#
#     stdnumeric_limitsD_round_error(...)
#         stdnumeric_limitsD_round_error() -> double
#
#     stdnumeric_limitsD_signaling_NaN(...)
#         stdnumeric_limitsD_signaling_NaN() -> double
#
#     stdnumeric_limitsF_denorm_min(...)
#         stdnumeric_limitsF_denorm_min() -> float
#
#     stdnumeric_limitsF_epsilon(...)
#         stdnumeric_limitsF_epsilon() -> float
#
#     stdnumeric_limitsF_infinity(...)
#         stdnumeric_limitsF_infinity() -> float
#
#     stdnumeric_limitsF_lowest(...)
#         stdnumeric_limitsF_lowest() -> float
#
#     stdnumeric_limitsF_max(...)
#         stdnumeric_limitsF_max() -> float
#
#     stdnumeric_limitsF_min(...)
#         stdnumeric_limitsF_min() -> float
#
#     stdnumeric_limitsF_quiet_NaN(...)
#         stdnumeric_limitsF_quiet_NaN() -> float
#
#     stdnumeric_limitsF_round_error(...)
#         stdnumeric_limitsF_round_error() -> float
#
#     stdnumeric_limitsF_signaling_NaN(...)
#         stdnumeric_limitsF_signaling_NaN() -> float
#
#     stdnumeric_limitsLD_denorm_min(...)
#         stdnumeric_limitsLD_denorm_min() -> long double
#
#     stdnumeric_limitsLD_epsilon(...)
#         stdnumeric_limitsLD_epsilon() -> long double
#
#     stdnumeric_limitsLD_infinity(...)
#         stdnumeric_limitsLD_infinity() -> long double
#
#     stdnumeric_limitsLD_lowest(...)
#         stdnumeric_limitsLD_lowest() -> long double
#
#     stdnumeric_limitsLD_max(...)
#         stdnumeric_limitsLD_max() -> long double
#
#     stdnumeric_limitsLD_min(...)
#         stdnumeric_limitsLD_min() -> long double
#
#     stdnumeric_limitsLD_quiet_NaN(...)
#         stdnumeric_limitsLD_quiet_NaN() -> long double
#
#     stdnumeric_limitsLD_round_error(...)
#         stdnumeric_limitsLD_round_error() -> long double
#
#     stdnumeric_limitsLD_signaling_NaN(...)
#         stdnumeric_limitsLD_signaling_NaN() -> long double
#
#     stdnumeric_limitsSC_denorm_min(...)
#         stdnumeric_limitsSC_denorm_min() -> signed char
#
#     stdnumeric_limitsSC_epsilon(...)
#         stdnumeric_limitsSC_epsilon() -> signed char
#
#     stdnumeric_limitsSC_infinity(...)
#         stdnumeric_limitsSC_infinity() -> signed char
#
#     stdnumeric_limitsSC_lowest(...)
#         stdnumeric_limitsSC_lowest() -> signed char
#
#     stdnumeric_limitsSC_max(...)
#         stdnumeric_limitsSC_max() -> signed char
#
#     stdnumeric_limitsSC_min(...)
#         stdnumeric_limitsSC_min() -> signed char
#
#     stdnumeric_limitsSC_quiet_NaN(...)
#         stdnumeric_limitsSC_quiet_NaN() -> signed char
#
#     stdnumeric_limitsSC_round_error(...)
#         stdnumeric_limitsSC_round_error() -> signed char
#
#     stdnumeric_limitsSC_signaling_NaN(...)
#         stdnumeric_limitsSC_signaling_NaN() -> signed char
#
#     stdnumeric_limitsSI_denorm_min(...)
#         stdnumeric_limitsSI_denorm_min() -> int
#
#     stdnumeric_limitsSI_epsilon(...)
#         stdnumeric_limitsSI_epsilon() -> int
#
#     stdnumeric_limitsSI_infinity(...)
#         stdnumeric_limitsSI_infinity() -> int
#
#     stdnumeric_limitsSI_lowest(...)
#         stdnumeric_limitsSI_lowest() -> int
#
#     stdnumeric_limitsSI_max(...)
#         stdnumeric_limitsSI_max() -> int
#
#     stdnumeric_limitsSI_min(...)
#         stdnumeric_limitsSI_min() -> int
#
#     stdnumeric_limitsSI_quiet_NaN(...)
#         stdnumeric_limitsSI_quiet_NaN() -> int
#
#     stdnumeric_limitsSI_round_error(...)
#         stdnumeric_limitsSI_round_error() -> int
#
#     stdnumeric_limitsSI_signaling_NaN(...)
#         stdnumeric_limitsSI_signaling_NaN() -> int
#
#     stdnumeric_limitsSL_denorm_min(...)
#         stdnumeric_limitsSL_denorm_min() -> long
#
#     stdnumeric_limitsSL_epsilon(...)
#         stdnumeric_limitsSL_epsilon() -> long
#
#     stdnumeric_limitsSL_infinity(...)
#         stdnumeric_limitsSL_infinity() -> long
#
#     stdnumeric_limitsSL_lowest(...)
#         stdnumeric_limitsSL_lowest() -> long
#
#     stdnumeric_limitsSL_max(...)
#         stdnumeric_limitsSL_max() -> long
#
#     stdnumeric_limitsSL_min(...)
#         stdnumeric_limitsSL_min() -> long
#
#     stdnumeric_limitsSL_quiet_NaN(...)
#         stdnumeric_limitsSL_quiet_NaN() -> long
#
#     stdnumeric_limitsSL_round_error(...)
#         stdnumeric_limitsSL_round_error() -> long
#
#     stdnumeric_limitsSL_signaling_NaN(...)
#         stdnumeric_limitsSL_signaling_NaN() -> long
#
#     stdnumeric_limitsSS_denorm_min(...)
#         stdnumeric_limitsSS_denorm_min() -> short
#
#     stdnumeric_limitsSS_epsilon(...)
#         stdnumeric_limitsSS_epsilon() -> short
#
#     stdnumeric_limitsSS_infinity(...)
#         stdnumeric_limitsSS_infinity() -> short
#
#     stdnumeric_limitsSS_lowest(...)
#         stdnumeric_limitsSS_lowest() -> short
#
#     stdnumeric_limitsSS_max(...)
#         stdnumeric_limitsSS_max() -> short
#
#     stdnumeric_limitsSS_min(...)
#         stdnumeric_limitsSS_min() -> short
#
#     stdnumeric_limitsSS_quiet_NaN(...)
#         stdnumeric_limitsSS_quiet_NaN() -> short
#
#     stdnumeric_limitsSS_round_error(...)
#         stdnumeric_limitsSS_round_error() -> short
#
#     stdnumeric_limitsSS_signaling_NaN(...)
#         stdnumeric_limitsSS_signaling_NaN() -> short
#
#     stdnumeric_limitsUC_denorm_min(...)
#         stdnumeric_limitsUC_denorm_min() -> unsigned char
#
#     stdnumeric_limitsUC_epsilon(...)
#         stdnumeric_limitsUC_epsilon() -> unsigned char
#
#     stdnumeric_limitsUC_infinity(...)
#         stdnumeric_limitsUC_infinity() -> unsigned char
#
#     stdnumeric_limitsUC_lowest(...)
#         stdnumeric_limitsUC_lowest() -> unsigned char
#
#     stdnumeric_limitsUC_max(...)
#         stdnumeric_limitsUC_max() -> unsigned char
#
#     stdnumeric_limitsUC_min(...)
#         stdnumeric_limitsUC_min() -> unsigned char
#
#     stdnumeric_limitsUC_quiet_NaN(...)
#         stdnumeric_limitsUC_quiet_NaN() -> unsigned char
#
#     stdnumeric_limitsUC_round_error(...)
#         stdnumeric_limitsUC_round_error() -> unsigned char
#
#     stdnumeric_limitsUC_signaling_NaN(...)
#         stdnumeric_limitsUC_signaling_NaN() -> unsigned char
#
#     stdnumeric_limitsUI_denorm_min(...)
#         stdnumeric_limitsUI_denorm_min() -> unsigned int
#
#     stdnumeric_limitsUI_epsilon(...)
#         stdnumeric_limitsUI_epsilon() -> unsigned int
#
#     stdnumeric_limitsUI_infinity(...)
#         stdnumeric_limitsUI_infinity() -> unsigned int
#
#     stdnumeric_limitsUI_lowest(...)
#         stdnumeric_limitsUI_lowest() -> unsigned int
#
#     stdnumeric_limitsUI_max(...)
#         stdnumeric_limitsUI_max() -> unsigned int
#
#     stdnumeric_limitsUI_min(...)
#         stdnumeric_limitsUI_min() -> unsigned int
#
#     stdnumeric_limitsUI_quiet_NaN(...)
#         stdnumeric_limitsUI_quiet_NaN() -> unsigned int
#
#     stdnumeric_limitsUI_round_error(...)
#         stdnumeric_limitsUI_round_error() -> unsigned int
#
#     stdnumeric_limitsUI_signaling_NaN(...)
#         stdnumeric_limitsUI_signaling_NaN() -> unsigned int
#
#     stdnumeric_limitsULL_denorm_min(...)
#         stdnumeric_limitsULL_denorm_min() -> unsigned long long
#
#     stdnumeric_limitsULL_epsilon(...)
#         stdnumeric_limitsULL_epsilon() -> unsigned long long
#
#     stdnumeric_limitsULL_infinity(...)
#         stdnumeric_limitsULL_infinity() -> unsigned long long
#
#     stdnumeric_limitsULL_lowest(...)
#         stdnumeric_limitsULL_lowest() -> unsigned long long
#
#     stdnumeric_limitsULL_max(...)
#         stdnumeric_limitsULL_max() -> unsigned long long
#
#     stdnumeric_limitsULL_min(...)
#         stdnumeric_limitsULL_min() -> unsigned long long
#
#     stdnumeric_limitsULL_quiet_NaN(...)
#         stdnumeric_limitsULL_quiet_NaN() -> unsigned long long
#
#     stdnumeric_limitsULL_round_error(...)
#         stdnumeric_limitsULL_round_error() -> unsigned long long
#
#     stdnumeric_limitsULL_signaling_NaN(...)
#         stdnumeric_limitsULL_signaling_NaN() -> unsigned long long
#
#     stdnumeric_limitsUL_denorm_min(...)
#         stdnumeric_limitsUL_denorm_min() -> unsigned long
#
#     stdnumeric_limitsUL_epsilon(...)
#         stdnumeric_limitsUL_epsilon() -> unsigned long
#
#     stdnumeric_limitsUL_infinity(...)
#         stdnumeric_limitsUL_infinity() -> unsigned long
#
#     stdnumeric_limitsUL_lowest(...)
#         stdnumeric_limitsUL_lowest() -> unsigned long
#
#     stdnumeric_limitsUL_max(...)
#         stdnumeric_limitsUL_max() -> unsigned long
#
#     stdnumeric_limitsUL_min(...)
#         stdnumeric_limitsUL_min() -> unsigned long
#
#     stdnumeric_limitsUL_quiet_NaN(...)
#         stdnumeric_limitsUL_quiet_NaN() -> unsigned long
#
#     stdnumeric_limitsUL_round_error(...)
#         stdnumeric_limitsUL_round_error() -> unsigned long
#
#     stdnumeric_limitsUL_signaling_NaN(...)
#         stdnumeric_limitsUL_signaling_NaN() -> unsigned long
#
#     stdnumeric_limitsUS_denorm_min(...)
#         stdnumeric_limitsUS_denorm_min() -> unsigned short
#
#     stdnumeric_limitsUS_epsilon(...)
#         stdnumeric_limitsUS_epsilon() -> unsigned short
#
#     stdnumeric_limitsUS_infinity(...)
#         stdnumeric_limitsUS_infinity() -> unsigned short
#
#     stdnumeric_limitsUS_lowest(...)
#         stdnumeric_limitsUS_lowest() -> unsigned short
#
#     stdnumeric_limitsUS_max(...)
#         stdnumeric_limitsUS_max() -> unsigned short
#
#     stdnumeric_limitsUS_min(...)
#         stdnumeric_limitsUS_min() -> unsigned short
#
#     stdnumeric_limitsUS_quiet_NaN(...)
#         stdnumeric_limitsUS_quiet_NaN() -> unsigned short
#
#     stdnumeric_limitsUS_round_error(...)
#         stdnumeric_limitsUS_round_error() -> unsigned short
#
#     stdnumeric_limitsUS_signaling_NaN(...)
#         stdnumeric_limitsUS_signaling_NaN() -> unsigned short
#
#     vnl_c_vectorCF_add(...)
#         vnl_c_vectorCF_add(stdcomplexF x, stdcomplexF y, stdcomplexF z, unsigned int arg3)
#         vnl_c_vectorCF_add(stdcomplexF x, stdcomplexF y, stdcomplexF z, unsigned int arg3)
#
#     vnl_c_vectorCF_allocate_T(...)
#         vnl_c_vectorCF_allocate_T(unsigned long const n) -> stdcomplexF
#
#     vnl_c_vectorCF_allocate_Tptr(...)
#         vnl_c_vectorCF_allocate_Tptr(unsigned long const n) -> stdcomplexF **
#
#     vnl_c_vectorCF_arg_max(...)
#         vnl_c_vectorCF_arg_max(stdcomplexF arg0, unsigned int arg1) -> unsigned int
#
#     vnl_c_vectorCF_arg_min(...)
#         vnl_c_vectorCF_arg_min(stdcomplexF arg0, unsigned int arg1) -> unsigned int
#
#     vnl_c_vectorCF_conjugate(...)
#         vnl_c_vectorCF_conjugate(stdcomplexF arg0, stdcomplexF arg1, unsigned int arg2)
#
#     vnl_c_vectorCF_copy(...)
#         vnl_c_vectorCF_copy(stdcomplexF x, stdcomplexF y, unsigned int arg2)
#
#     vnl_c_vectorCF_deallocate(...)
#         vnl_c_vectorCF_deallocate(stdcomplexF ** arg0, unsigned long const n_when_allocated)
#         vnl_c_vectorCF_deallocate(stdcomplexF arg0, unsigned long const n_when_allocated)
#
#     vnl_c_vectorCF_divide(...)
#         vnl_c_vectorCF_divide(stdcomplexF x, stdcomplexF y, stdcomplexF z, unsigned int arg3)
#         vnl_c_vectorCF_divide(stdcomplexF x, stdcomplexF y, stdcomplexF z, unsigned int arg3)
#
#     vnl_c_vectorCF_dot_product(...)
#         vnl_c_vectorCF_dot_product(stdcomplexF arg0, stdcomplexF arg1, unsigned int arg2) -> stdcomplexF
#
#     vnl_c_vectorCF_euclid_dist_sq(...)
#         vnl_c_vectorCF_euclid_dist_sq(stdcomplexF arg0, stdcomplexF arg1, unsigned int arg2) -> stdcomplexF
#
#     vnl_c_vectorCF_fill(...)
#         vnl_c_vectorCF_fill(stdcomplexF x, unsigned int arg1, stdcomplexF v)
#
#     vnl_c_vectorCF_inf_norm(...)
#         vnl_c_vectorCF_inf_norm(stdcomplexF p, unsigned int n) -> float
#
#     vnl_c_vectorCF_inner_product(...)
#         vnl_c_vectorCF_inner_product(stdcomplexF arg0, stdcomplexF arg1, unsigned int arg2) -> stdcomplexF
#
#     vnl_c_vectorCF_invert(...)
#         vnl_c_vectorCF_invert(stdcomplexF x, stdcomplexF y, unsigned int arg2)
#
#     vnl_c_vectorCF_max_value(...)
#         vnl_c_vectorCF_max_value(stdcomplexF arg0, unsigned int arg1) -> stdcomplexF
#
#     vnl_c_vectorCF_mean(...)
#         vnl_c_vectorCF_mean(stdcomplexF p, unsigned int n) -> stdcomplexF
#
#     vnl_c_vectorCF_min_value(...)
#         vnl_c_vectorCF_min_value(stdcomplexF arg0, unsigned int arg1) -> stdcomplexF
#
#     vnl_c_vectorCF_multiply(...)
#         vnl_c_vectorCF_multiply(stdcomplexF x, stdcomplexF y, stdcomplexF z, unsigned int arg3)
#         vnl_c_vectorCF_multiply(stdcomplexF x, stdcomplexF y, stdcomplexF z, unsigned int arg3)
#
#     vnl_c_vectorCF_negate(...)
# ...
#     ReconstructionByDilationImageFilter = <itkTemplate itk::Reconstruction...
#     ReconstructionByErosionImageFilter = <itkTemplate itk::ReconstructionB...
#     RecursiveGaussianImageFilter = <itkTemplate itk::RecursiveGaussianImag...
#     RecursiveMultiResolutionPyramidImageFilter = <itkTemplate itk::Recursi...
#     RecursiveSeparableImageFilter = <itkTemplate itk::RecursiveSeparableIm...
#     RegionFromReferenceLabelMapFilter = <itkTemplate itk::RegionFromRefere...
#     RegionOfInterestImageFilter = <itkTemplate itk::RegionOfInterestImageF...
#     RegionalMaximaImageFilter = <itkTemplate itk::RegionalMaximaImageFilte...
#     RegionalMinimaImageFilter = <itkTemplate itk::RegionalMinimaImageFilte...
#     RegistrationParameterScalesFromPhysicalShift = <itkTemplate itk::Regis...
#     RegularStepGradientDescentOptimizerv4 = <itkTemplate itk::RegularStepG...
#     ReinitializeLevelSetImageFilter = <itkTemplate itk::ReinitializeLevelS...
#     RelabelComponentImageFilter = <itkTemplate itk::RelabelComponentImageF...
#     RelabelLabelMapFilter = <itkTemplate itk::RelabelLabelMapFilter>
#     RenyiEntropyThresholdCalculator = <itkTemplate itk::RenyiEntropyThresh...
#     RenyiEntropyThresholdImageFilter = <itkTemplate itk::RenyiEntropyThres...
#     ResampleImageFilter = <itkTemplate itk::ResampleImageFilter>
#     RescaleIntensityImageFilter = <itkTemplate itk::RescaleIntensityImageF...
#     ResourceProbe = <itkTemplate itk::ResourceProbe>
#     RichardsonLucyDeconvolutionImageFilter = <itkTemplate itk::RichardsonL...
#     Rigid2DTransform = <itkTemplate itk::Rigid2DTransform>
#     Rigid3DPerspectiveTransform = <itkTemplate itk::Rigid3DPerspectiveTran...
#     Rigid3DTransform = <itkTemplate itk::Rigid3DTransform>
#     RoundImageFilter = <itkTemplate itk::RoundImageFilter>
#     SC = <itkCType signed char>
#     SI = <itkCType signed int>
#     SL = <itkCType signed long>
#     SLICImageFilter = <itkTemplate itk::SLICImageFilter>
#     SLL = <itkCType signed long long>
#     SS = <itkCType signed short>
#     STAPLEImageFilter = <itkTemplate itk::STAPLEImageFilter>
#     SaltAndPepperNoiseImageFilter = <itkTemplate itk::SaltAndPepperNoiseIm...
#     Sample = <itkTemplate itk::Statistics::Sample>
#     ScalableAffineTransform = <itkTemplate itk::ScalableAffineTransform>
#     ScalarConnectedComponentImageFilter = <itkTemplate itk::ScalarConnecte...
#     ScalarImageKmeansImageFilter = <itkTemplate itk::ScalarImageKmeansImag...
#     ScalarImageToCooccurrenceMatrixFilter = <itkTemplate itk::Statistics::...
#     ScalarImageToHistogramGenerator = <itkTemplate itk::Statistics::Scalar...
#     ScalarImageToRunLengthFeaturesFilter = <itkTemplate itk::Statistics::S...
#     ScalarImageToRunLengthMatrixFilter = <itkTemplate itk::Statistics::Sca...
#     ScalarImageToTextureFeaturesFilter = <itkTemplate itk::Statistics::Sca...
#     ScalarToRGBColormapImageFilter = <itkTemplate itk::ScalarToRGBColormap...
#     ScaleLogarithmicTransform = <itkTemplate itk::ScaleLogarithmicTransfor...
#     ScaleSkewVersor3DTransform = <itkTemplate itk::ScaleSkewVersor3DTransf...
#     ScaleTransform = <itkTemplate itk::ScaleTransform>
#     ScaleVersor3DTransform = <itkTemplate itk::ScaleVersor3DTransform>
#     ScanlineFilterCommon = <itkTemplate itk::ScanlineFilterCommon>
#     SegmentationLevelSetFunction = <itkTemplate itk::SegmentationLevelSetF...
#     SegmentationLevelSetImageFilter = <itkTemplate itk::SegmentationLevelS...
#     ShanbhagThresholdCalculator = <itkTemplate itk::ShanbhagThresholdCalcu...
#     ShanbhagThresholdImageFilter = <itkTemplate itk::ShanbhagThresholdImag...
#     ShapeDetectionLevelSetImageFilter = <itkTemplate itk::ShapeDetectionLe...
#     ShapeKeepNObjectsLabelMapFilter = <itkTemplate itk::ShapeKeepNObjectsL...
#     ShapeLabelMapFilter = <itkTemplate itk::ShapeLabelMapFilter>
#     ShapeLabelObject = <itkTemplate itk::ShapeLabelObject>
#     ShapeOpeningLabelMapFilter = <itkTemplate itk::ShapeOpeningLabelMapFil...
#     ShapePositionLabelMapFilter = <itkTemplate itk::ShapePositionLabelMapF...
#     ShapePriorMAPCostFunction = <itkTemplate itk::ShapePriorMAPCostFunctio...
#     ShapePriorMAPCostFunctionBase = <itkTemplate itk::ShapePriorMAPCostFun...
#     ShapePriorSegmentationLevelSetImageFilter = <itkTemplate itk::ShapePri...
#     ShapeRelabelImageFilter = <itkTemplate itk::ShapeRelabelImageFilter>
#     ShapeRelabelLabelMapFilter = <itkTemplate itk::ShapeRelabelLabelMapFil...
#     ShapeSignedDistanceFunction = <itkTemplate itk::ShapeSignedDistanceFun...
#     ShapeUniqueLabelMapFilter = <itkTemplate itk::ShapeUniqueLabelMapFilte...
#     ShiftScaleImageFilter = <itkTemplate itk::ShiftScaleImageFilter>
#     ShiftScaleLabelMapFilter = <itkTemplate itk::ShiftScaleLabelMapFilter>
#     ShotNoiseImageFilter = <itkTemplate itk::ShotNoiseImageFilter>
#     ShrinkImageFilter = <itkTemplate itk::ShrinkImageFilter>
#     SigmoidImageFilter = <itkTemplate itk::SigmoidImageFilter>
#     SignedDanielssonDistanceMapImageFilter = <itkTemplate itk::SignedDanie...
#     SignedMaurerDistanceMapImageFilter = <itkTemplate itk::SignedMaurerDis...
#     Similarity2DTransform = <itkTemplate itk::Similarity2DTransform>
#     Similarity3DTransform = <itkTemplate itk::Similarity3DTransform>
#     SimilarityIndexImageFilter = <itkTemplate itk::SimilarityIndexImageFil...
#     SimpleContourExtractorImageFilter = <itkTemplate itk::SimpleContourExt...
#     SimpleDataObjectDecorator = <itkTemplate itk::SimpleDataObjectDecorato...
#     SinImageFilter = <itkTemplate itk::SinImageFilter>
#     SingleValuedCostFunctionv4Template = <itkTemplate itk::SingleValuedCos...
#     Size = <itkTemplate itk::Size>
#     SliceBySliceImageFilter = <itkTemplate itk::SliceBySliceImageFilter>
#     SmoothingQuadEdgeMeshFilter = <itkTemplate itk::SmoothingQuadEdgeMeshF...
#     SmoothingRecursiveGaussianImageFilter = <itkTemplate itk::SmoothingRec...
#     SobelEdgeDetectionImageFilter = <itkTemplate itk::SobelEdgeDetectionIm...
#     SobelOperator = <itkTemplate itk::SobelOperator>
#     SparseFieldFourthOrderLevelSetImageFilter = <itkTemplate itk::SparseFi...
#     SparseFieldLayer = <itkTemplate itk::SparseFieldLayer>
#     SparseFieldLevelSetImageFilter = <itkTemplate itk::SparseFieldLevelSet...
#     SparseFieldLevelSetNode = <itkTemplate itk::SparseFieldLevelSetNode>
#     SparseImage = <itkTemplate itk::SparseImage>
#     SpatialFunction = <itkTemplate itk::SpatialFunction>
#     SpatialObject = <itkTemplate itk::SpatialObject>
#     SpatialObjectPoint = <itkTemplate itk::SpatialObjectPoint>
#     SpatialObjectReader = <itkTemplate itk::SpatialObjectReader>
#     SpatialObjectToImageFilter = <itkTemplate itk::SpatialObjectToImageFil...
#     SpatialObjectWriter = <itkTemplate itk::SpatialObjectWriter>
#     SpeckleNoiseImageFilter = <itkTemplate itk::SpeckleNoiseImageFilter>
#     SqrtImageFilter = <itkTemplate itk::SqrtImageFilter>
#     SquareImageFilter = <itkTemplate itk::SquareImageFilter>
#     SquaredDifferenceImageFilter = <itkTemplate itk::SquaredDifferenceImag...
#     StandardDeviationProjectionImageFilter = <itkTemplate itk::StandardDev...
#     StatisticsImageFilter = <itkTemplate itk::StatisticsImageFilter>
#     StatisticsKeepNObjectsLabelMapFilter = <itkTemplate itk::StatisticsKee...
#     StatisticsLabelMapFilter = <itkTemplate itk::StatisticsLabelMapFilter>
#     StatisticsLabelObject = <itkTemplate itk::StatisticsLabelObject>
#     StatisticsOpeningLabelMapFilter = <itkTemplate itk::StatisticsOpeningL...
#     StatisticsPositionLabelMapFilter = <itkTemplate itk::StatisticsPositio...
#     StatisticsRelabelImageFilter = <itkTemplate itk::StatisticsRelabelImag...
#     StatisticsRelabelLabelMapFilter = <itkTemplate itk::StatisticsRelabelL...
#     StatisticsUniqueLabelMapFilter = <itkTemplate itk::StatisticsUniqueLab...
#     StreamingImageFilter = <itkTemplate itk::StreamingImageFilter>
#     SubtractImageFilter = <itkTemplate itk::SubtractImageFilter>
#     SumProjectionImageFilter = <itkTemplate itk::SumProjectionImageFilter>
#     SurfaceSpatialObject = <itkTemplate itk::SurfaceSpatialObject>
#     SurfaceSpatialObjectPoint = <itkTemplate itk::SurfaceSpatialObjectPoin...
#     SymmetricEigenAnalysisImageFilter = <itkTemplate itk::SymmetricEigenAn...
#     SymmetricForcesDemonsRegistrationFilter = <itkTemplate itk::SymmetricF...
#     SymmetricSecondRankTensor = <itkTemplate itk::SymmetricSecondRankTenso...
#     TanImageFilter = <itkTemplate itk::TanImageFilter>
#     TernaryAddImageFilter = <itkTemplate itk::TernaryAddImageFilter>
#     TernaryMagnitudeImageFilter = <itkTemplate itk::TernaryMagnitudeImageF...
#     TernaryMagnitudeSquaredImageFilter = <itkTemplate itk::TernaryMagnitud...
#     ThinPlateR2LogRSplineKernelTransform = <itkTemplate itk::ThinPlateR2Lo...
#     ThinPlateSplineKernelTransform = <itkTemplate itk::ThinPlateSplineKern...
#     ThresholdImageFilter = <itkTemplate itk::ThresholdImageFilter>
#     ThresholdLabelerImageFilter = <itkTemplate itk::ThresholdLabelerImageF...
#     ThresholdMaximumConnectedComponentsImageFilter = <itkTemplate itk::Thr...
#     ThresholdSegmentationLevelSetImageFilter = <itkTemplate itk::Threshold...
#     TikhonovDeconvolutionImageFilter = <itkTemplate itk::TikhonovDeconvolu...
#     TileImageFilter = <itkTemplate itk::TileImageFilter>
#     TimeVaryingVelocityFieldTransform = <itkTemplate itk::TimeVaryingVeloc...
#     TobogganImageFilter = <itkTemplate itk::TobogganImageFilter>
#     Transform = <itkTemplate itk::Transform>
#     TransformBaseTemplate = <itkTemplate itk::TransformBaseTemplate>
#     TransformFileReaderTemplate = <itkTemplate itk::TransformFileReaderTem...
#     TransformFileWriterTemplate = <itkTemplate itk::TransformFileWriterTem...
#     TransformIOBaseTemplate = <itkTemplate itk::TransformIOBaseTemplate>
#     TransformMeshFilter = <itkTemplate itk::TransformMeshFilter>
#     TransformParametersAdaptorBase = <itkTemplate itk::TransformParameters...
#     TranslationTransform = <itkTemplate itk::TranslationTransform>
#     TriangleHelper = <itkTemplate itk::TriangleHelper>
#     TriangleMeshToBinaryImageFilter = <itkTemplate itk::TriangleMeshToBina...
#     TriangleThresholdCalculator = <itkTemplate itk::TriangleThresholdCalcu...
#     TriangleThresholdImageFilter = <itkTemplate itk::TriangleThresholdImag...
#     TubeSpatialObject = <itkTemplate itk::TubeSpatialObject>
#     TubeSpatialObjectPoint = <itkTemplate itk::TubeSpatialObjectPoint>
#     UC = <itkCType unsigned char>
#     UI = <itkCType unsigned int>
#     UL = <itkCType unsigned long>
#     ULL = <itkCType unsigned long long>
#     US = <itkCType unsigned short>
#     UnaryFrequencyDomainFilter = <itkTemplate itk::UnaryFrequencyDomainFil...
#     UnaryGeneratorImageFilter = <itkTemplate itk::UnaryGeneratorImageFilte...
#     UnsharpMaskImageFilter = <itkTemplate itk::UnsharpMaskImageFilter>
#     UnsharpMaskLevelSetImageFilter = <itkTemplate itk::UnsharpMaskLevelSet...
#     VTKImageExport = <itkTemplate itk::VTKImageExport>
#     VTKImageImport = <itkTemplate itk::VTKImageImport>
#     VTKPolyDataReader = <itkTemplate itk::VTKPolyDataReader>
#     VTKPolyDataWriter = <itkTemplate itk::VTKPolyDataWriter>
#     ValuedRegionalMaximaImageFilter = <itkTemplate itk::ValuedRegionalMaxi...
#     ValuedRegionalMinimaImageFilter = <itkTemplate itk::ValuedRegionalMini...
#     VariableLengthVector = <itkTemplate itk::VariableLengthVector>
#     VariableSizeMatrix = <itkTemplate itk::VariableSizeMatrix>
#     Vector = <itkTemplate itk::Vector>
#     VectorConfidenceConnectedImageFilter = <itkTemplate itk::VectorConfide...
#     VectorConnectedComponentImageFilter = <itkTemplate itk::VectorConnecte...
#     VectorContainer = <itkTemplate itk::VectorContainer>
#     VectorCurvatureAnisotropicDiffusionImageFilter = <itkTemplate itk::Vec...
#     VectorGradientAnisotropicDiffusionImageFilter = <itkTemplate itk::Vect...
#     VectorGradientMagnitudeImageFilter = <itkTemplate itk::VectorGradientM...
#     VectorImage = <itkTemplate itk::VectorImage>
#     VectorIndexSelectionCastImageFilter = <itkTemplate itk::VectorIndexSel...
#     VectorMagnitudeImageFilter = <itkTemplate itk::VectorMagnitudeImageFil...
#     VectorRescaleIntensityImageFilter = <itkTemplate itk::VectorRescaleInt...
#     VectorThresholdSegmentationLevelSetImageFilter = <itkTemplate itk::Vec...
#     VelocityFieldTransform = <itkTemplate itk::VelocityFieldTransform>
#     Versor = <itkTemplate itk::Versor>
#     VersorRigid3DTransform = <itkTemplate itk::VersorRigid3DTransform>
#     VersorTransform = <itkTemplate itk::VersorTransform>
#     VnlComplexToComplexFFTImageFilter = <itkTemplate itk::VnlComplexToComp...
#     VnlForwardFFTImageFilter = <itkTemplate itk::VnlForwardFFTImageFilter>
#     VnlHalfHermitianToRealInverseFFTImageFilter = <itkTemplate itk::VnlHal...
#     VnlInverseFFTImageFilter = <itkTemplate itk::VnlInverseFFTImageFilter>
#     VnlRealToHalfHermitianForwardFFTImageFilter = <itkTemplate itk::VnlRea...
#     VolumeSplineKernelTransform = <itkTemplate itk::VolumeSplineKernelTran...
#     VoronoiSegmentationImageFilter = <itkTemplate itk::VoronoiSegmentation...
#     VotingBinaryHoleFillingImageFilter = <itkTemplate itk::VotingBinaryHol...
#     VotingBinaryImageFilter = <itkTemplate itk::VotingBinaryImageFilter>
#     VotingBinaryIterativeHoleFillingImageFilter = <itkTemplate itk::Voting...
#     WarpImageFilter = <itkTemplate itk::WarpImageFilter>
#     WatershedImageFilter = <itkTemplate itk::WatershedImageFilter>
#     WeightedAddImageFilter = <itkTemplate itk::WeightedAddImageFilter>
#     WeightedCentroidKdTreeGenerator = <itkTemplate itk::Statistics::Weight...
#     WelchWindowFunction = <itkTemplate itk::Function::WelchWindowFunction>
#     WhiteTopHatImageFilter = <itkTemplate itk::WhiteTopHatImageFilter>
#     WienerDeconvolutionImageFilter = <itkTemplate itk::WienerDeconvolution...
#     WindowedSincInterpolateImageFunction = <itkTemplate itk::WindowedSincI...
#     WrapPadImageFilter = <itkTemplate itk::WrapPadImageFilter>
#     XorImageFilter = <itkTemplate itk::XorImageFilter>
#     YenThresholdCalculator = <itkTemplate itk::YenThresholdCalculator>
#     YenThresholdImageFilter = <itkTemplate itk::YenThresholdImageFilter>
#     ZeroCrossingBasedEdgeDetectionImageFilter = <itkTemplate itk::ZeroCros...
#     ZeroCrossingImageFilter = <itkTemplate itk::ZeroCrossingImageFilter>
#     ZeroFluxNeumannBoundaryCondition = <itkTemplate itk::ZeroFluxNeumannBo...
#     ZeroFluxNeumannPadImageFilter = <itkTemplate itk::ZeroFluxNeumannPadIm...
#     cerr = <itk.pyBasePython.ostream; proxy of <Swig Object of type 'std::...
#     cin = <Swig Object of type 'std::istream *'>
#     clog = <itk.pyBasePython.ostream; proxy of <Swig Object of type 'std::...
#     clrLine = '\x1b[2000D\x1b[K'
#     complex = <itkTemplate std::complex>
#     cout = <itk.pyBasePython.ostream; proxy of <Swig Object of type 'std::...
#     cvar = <Swig global variables>
#     endl_cb_ptr = <Swig Object of type 'std::basic_ostream< char,s...sic_o...
#     ends_cb_ptr = <Swig Object of type 'std::basic_ostream< char,s...sic_o...
#     flush_cb_ptr = <Swig Object of type 'std::basic_ostream< char,s...sic_...
#     lazy_attributes = {'AbortCheckEvent': ['ITKCommon'], 'AbortEvent': ['I...
#     list = <itkTemplate std::list>
#     loaded_lazy_modules = {'ITKAnisotropicSmoothing', 'ITKAntiAlias', 'ITK...
#     map = <itkTemplate std::map>
#     numeric_limits = <itkTemplate std::numeric_limits>
#     set = <itkTemplate std::set>
#     swig = {'SwigPyIterator': <class 'itk.pyBasePython.SwigPyIterator'>, '...
#     vector = <itkTemplate std::vector>
#     vnl_c_vector = <itkTemplate vnl_c_vector>
#     vnl_diag_matrix = <itkTemplate vnl_diag_matrix>
#     vnl_file_matrix = <itkTemplate vnl_file_matrix>
#     vnl_file_vector = <itkTemplate vnl_file_vector>
#     vnl_fortran_copy = <itkTemplate vnl_fortran_copy>
#     vnl_matrix = <itkTemplate vnl_matrix>
#     vnl_matrix_fixed = <itkTemplate vnl_matrix_fixed>
#     vnl_matrix_fixed_ref = <itkTemplate vnl_matrix_fixed_ref>
#     vnl_matrix_fixed_ref_const = <itkTemplate vnl_matrix_fixed_ref_const>
#     vnl_matrix_ref = <itkTemplate vnl_matrix_ref>
#     vnl_unary_function = <itkTemplate vnl_unary_function>
#     vnl_vector = <itkTemplate vnl_vector>
#     vnl_vector_ref = <itkTemplate vnl_vector_ref>
#
# FILE
#     (built-in)

# %%
import numpy as np

from itkwidgets import view

from Parser import Parser

parser = Parser('./sample-output')

cells = parser.getFrame(0).cells


print(type(cells.data))

v = view(point_sets=[cells.data[1:4].T])
v
# Out:
# <class 'numpy.ndarray'>
# Viewer(geometries=[], gradient_opacity=0.22, point_set_colors=array([[0.8392157, 0.       , 0.       ]], dtype…

# %%
import pyvista as pv
from Parser import Parser

parser = Parser('./sample-output')
cells = parser.getFrame(0).cells

# mesh = pyvista.Sphere()
pl = pv.PlotterITK()  
pl.add_points(cells.data[1:4].T)
pl.show()
# Out:
# Viewer(geometries=[], point_set_colors=array([[1., 1., 1.]], dtype=float32), point_set_opacities=array([1.], d…
# Viewer(geometries=[], point_set_colors=array([[1., 1., 1.]], dtype=float32), point_set_opacities=array([1.], d…

# %%
# Out:
# Requirement already satisfied: pyvista in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (0.29.0)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyvista) (1.20.0)
# Requirement already satisfied: appdirs in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyvista) (1.4.4)
# Requirement already satisfied: imageio in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyvista) (2.9.0)
# Requirement already satisfied: vtk in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyvista) (9.0.1)
# Requirement already satisfied: meshio<5.0,>=4.0.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyvista) (4.3.11)
# Requirement already satisfied: scooby>=0.5.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyvista) (0.5.6)
# Requirement already satisfied: pillow in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyvista) (8.1.0)
# Requirement already satisfied: transforms3d==0.3.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyvista) (0.3.1)

# %%
import vtk

dir(vtk)
# Out:
# ['EnsightReaderCellIdMode',
#  'IMPLICIT_STRUCTURED_MODE',
#  'NON_SPARSE_MODE',
#  'SINGLE_PROCESS_MODE',
#  'SPARSE_MODE',
#  'VTKIS_ACTOR',
#  'VTKIS_ANIM_OFF',
#  'VTKIS_ANIM_ON',
#  'VTKIS_CAMERA',
#  'VTKIS_CLIP',
#  'VTKIS_DOLLY',
#  'VTKIS_ENV_ROTATE',
#  'VTKIS_EXIT',
#  'VTKIS_FORWARDFLY',
#  'VTKIS_GESTURE',
#  'VTKIS_IMAGE2D',
#  'VTKIS_IMAGE3D',
#  'VTKIS_IMAGE_SLICING',
#  'VTKIS_JOYSTICK',
#  'VTKIS_LOAD_CAMERA_POSE',
#  'VTKIS_MENU',
#  'VTKIS_NONE',
#  'VTKIS_PAN',
#  'VTKIS_PICK',
#  'VTKIS_POSITION_PROP',
#  'VTKIS_REVERSEFLY',
#  'VTKIS_ROTATE',
#  'VTKIS_SLICE',
#  'VTKIS_SPIN',
#  'VTKIS_START',
#  'VTKIS_TIMER',
#  'VTKIS_TOGGLE_DRAW_CONTROLS',
#  'VTKIS_TRACKBALL',
#  'VTKIS_TWO_POINTER',
#  'VTKIS_USCALE',
#  'VTKIS_USERINTERACTION',
#  'VTKIS_WINDOW_LEVEL',
#  'VTKIS_ZOOM',
#  'VTKI_MAX_POINTERS',
#  'VTKI_TIMER_FIRST',
#  'VTKI_TIMER_UPDATE',
#  'VTKKW_FPMM_SHIFT',
#  'VTKKW_FP_MASK',
#  'VTKKW_FP_SCALE',
#  'VTKKW_FP_SHIFT',
#  'VTK_21_POINT_WEDGE',
#  'VTK_3D_EXTENT',
#  'VTK_ABS',
#  'VTK_ACCUMULATION_MODE_MAX',
#  'VTK_ACCUMULATION_MODE_MIN',
#  'VTK_ACCUMULATION_MODE_SUM',
#  'VTK_ADD',
#  'VTK_ADDC',
#  'VTK_AND',
#  'VTK_ARIAL',
#  'VTK_ARRAY_DATA',
#  'VTK_ARROW_GLYPH',
#  'VTK_ASCII',
#  'VTK_ATAN',
#  'VTK_ATAN2',
#  'VTK_ATTRIBUTE_MODE_DEFAULT',
#  'VTK_ATTRIBUTE_MODE_USE_CELL_DATA',
#  'VTK_ATTRIBUTE_MODE_USE_EDGE_DATA',
#  'VTK_ATTRIBUTE_MODE_USE_POINT_DATA',
#  'VTK_ATTRIBUTE_MODE_USE_VERTEX_DATA',
#  'VTK_BACKGROUND_LOCATION',
#  'VTK_BEST_FITTING_PLANE',
#  'VTK_BEZIER_CURVE',
#  'VTK_BEZIER_HEXAHEDRON',
#  'VTK_BEZIER_PYRAMID',
#  'VTK_BEZIER_QUADRILATERAL',
#  'VTK_BEZIER_TETRAHEDRON',
#  'VTK_BEZIER_TRIANGLE',
#  'VTK_BEZIER_WEDGE',
#  'VTK_BIG_ENDIAN',
#  'VTK_BINARY',
#  'VTK_BIQUADRATIC_QUAD',
#  'VTK_BIQUADRATIC_QUADRATIC_HEXAHEDRON',
#  'VTK_BIQUADRATIC_QUADRATIC_WEDGE',
#  'VTK_BIQUADRATIC_TRIANGLE',
#  'VTK_BIT',
#  'VTK_BIT_MAX',
#  'VTK_BIT_MIN',
#  'VTK_BLACKMAN_HARRIS3',
#  'VTK_BLACKMAN_HARRIS4',
#  'VTK_BLACKMAN_NUTTALL3',
#  'VTK_BLACKMAN_NUTTALL4',
#  'VTK_BLACKMAN_WINDOW',
#  'VTK_BODR_DATA_PATH_BUILD',
#  'VTK_BOX_TYPE_AXIS_ALIGNED',
#  'VTK_BOX_TYPE_ORIENTED',
#  'VTK_BSPLINE_EDGE',
#  'VTK_BSPLINE_ZERO',
#  'VTK_BSPLINE_ZERO_AT_BORDER',
#  'VTK_BUILD_VERSION',
#  'VTK_BUNYKRCF_ARRAY_SIZE',
#  'VTK_BUNYKRCF_MAX_ARRAYS',
#  'VTK_CCS_SCALAR_MODE_COLORS',
#  'VTK_CCS_SCALAR_MODE_LABELS',
#  'VTK_CCS_SCALAR_MODE_NONE',
#  'VTK_CELL_DATA',
#  'VTK_CELL_DATA_FIELD',
#  'VTK_CELL_MODE',
#  'VTK_CELL_SIZE',
#  'VTK_CHAR',
#  'VTK_CHAR_MAX',
#  'VTK_CHAR_MIN',
#  'VTK_CIRCLE_GLYPH',
#  'VTK_COLOR_BY_INPUT',
#  'VTK_COLOR_BY_SCALAR',
#  'VTK_COLOR_BY_SCALE',
#  'VTK_COLOR_BY_SOURCE',
#  'VTK_COLOR_BY_VECTOR',
#  'VTK_COLOR_MODE_DEFAULT',
#  'VTK_COLOR_MODE_DIRECT_SCALARS',
#  'VTK_COLOR_MODE_LINEAR_256',
#  'VTK_COLOR_MODE_LUT',
#  'VTK_COLOR_MODE_MAP_SCALARS',
#  'VTK_COLOR_MODE_OFF',
#  'VTK_COLOR_MODE_UNIFORM_CELL_COLOR',
#  'VTK_COLOR_MODE_UNIFORM_COLOR',
#  'VTK_COLOR_MODE_UNIFORM_POINT_COLOR',
#  'VTK_COMPLEX_MULTIPLY',
#  'VTK_COMPONENT_MODE_USE_ALL',
#  'VTK_COMPONENT_MODE_USE_ANY',
#  'VTK_COMPONENT_MODE_USE_SELECTED',
#  'VTK_COMPOSITE_DATA_SET',
#  'VTK_CONJUGATE',
#  'VTK_CONVEX_POINT_SET',
#  'VTK_COS',
#  'VTK_COSINE_WINDOW',
#  'VTK_COURIER',
#  'VTK_CROP_CROSS',
#  'VTK_CROP_FENCE',
#  'VTK_CROP_INVERTED_CROSS',
#  'VTK_CROP_INVERTED_FENCE',
#  'VTK_CROP_SUBVOLUME',
#  'VTK_CROSS_GLYPH',
#  'VTK_CTF_DIVERGING',
#  'VTK_CTF_HSV',
#  'VTK_CTF_LAB',
#  'VTK_CTF_LAB_CIEDE2000',
#  'VTK_CTF_LINEAR',
#  'VTK_CTF_LOG10',
#  'VTK_CTF_RGB',
#  'VTK_CTF_STEP',
#  'VTK_CUBIC_INTERPOLATION',
#  'VTK_CUBIC_LINE',
#  'VTK_CUBIC_RESLICE',
#  'VTK_CULLER_SORT_BACK_TO_FRONT',
#  'VTK_CULLER_SORT_FRONT_TO_BACK',
#  'VTK_CULLER_SORT_NONE',
#  'VTK_CURSOR_ARROW',
#  'VTK_CURSOR_CROSSHAIR',
#  'VTK_CURSOR_DEFAULT',
#  'VTK_CURSOR_HAND',
#  'VTK_CURSOR_SIZEALL',
#  'VTK_CURSOR_SIZENE',
#  'VTK_CURSOR_SIZENS',
#  'VTK_CURSOR_SIZENW',
#  'VTK_CURSOR_SIZESE',
#  'VTK_CURSOR_SIZESW',
#  'VTK_CURSOR_SIZEWE',
#  'VTK_CURVATURE_GAUSS',
#  'VTK_CURVATURE_MAXIMUM',
#  'VTK_CURVATURE_MEAN',
#  'VTK_CURVATURE_MINIMUM',
#  'VTK_CXX_COMPILER',
#  'VTK_DASH_GLYPH',
#  'VTK_DATA_OBJECT',
#  'VTK_DATA_OBJECT_FIELD',
#  'VTK_DATA_SCALING_OFF',
#  'VTK_DATA_SET',
#  'VTK_DBL_EPSILON',
#  'VTK_DBL_MIN',
#  'VTK_DEFAULT_NUMBER_OF_RADIAL_AXES',
#  'VTK_DELAUNAY_XY_PLANE',
#  'VTK_DENSITY_ESTIMATE_FIXED_RADIUS',
#  'VTK_DENSITY_ESTIMATE_RELATIVE_RADIUS',
#  'VTK_DENSITY_FORM_NPTS',
#  'VTK_DENSITY_FORM_VOLUME_NORM',
#  'VTK_DIAMOND_GLYPH',
#  'VTK_DICE_MODE_MEMORY_LIMIT',
#  'VTK_DICE_MODE_NUMBER_OF_POINTS',
#  'VTK_DICE_MODE_SPECIFIED_NUMBER',
#  'VTK_DIRECTED_ACYCLIC_GRAPH',
#  'VTK_DIRECTED_GRAPH',
#  'VTK_DISPLAY',
#  'VTK_DIVIDE',
#  'VTK_DOUBLE',
#  'VTK_DOUBLE_MAX',
#  'VTK_DOUBLE_MIN',
#  'VTK_EDGEARROW_GLYPH',
#  'VTK_EDGE_OVERLAP',
#  'VTK_EDT_SAITO',
#  'VTK_EDT_SAITO_CACHED',
#  'VTK_EMPTY',
#  'VTK_EMPTY_CELL',
#  'VTK_ENCODING_ISO_8859_1',
#  'VTK_ENCODING_ISO_8859_10',
#  'VTK_ENCODING_ISO_8859_11',
#  'VTK_ENCODING_ISO_8859_12',
#  'VTK_ENCODING_ISO_8859_13',
#  'VTK_ENCODING_ISO_8859_14',
#  'VTK_ENCODING_ISO_8859_15',
#  'VTK_ENCODING_ISO_8859_16',
#  'VTK_ENCODING_ISO_8859_2',
#  'VTK_ENCODING_ISO_8859_3',
#  'VTK_ENCODING_ISO_8859_4',
#  'VTK_ENCODING_ISO_8859_5',
#  'VTK_ENCODING_ISO_8859_6',
#  'VTK_ENCODING_ISO_8859_7',
#  'VTK_ENCODING_ISO_8859_8',
#  'VTK_ENCODING_ISO_8859_9',
#  'VTK_ENCODING_NONE',
#  'VTK_ENCODING_UNICODE',
#  'VTK_ENCODING_UNKNOWN',
#  'VTK_ENCODING_US_ASCII',
#  'VTK_ENCODING_UTF_8',
#  'VTK_ERROR',
#  'VTK_ERROR_ABSOLUTE',
#  'VTK_ERROR_NUMBER_OF_TRIANGLES',
#  'VTK_ERROR_RELATIVE',
#  'VTK_ERROR_SPECIFIED_REDUCTION',
#  'VTK_EXP',
#  'VTK_EXPLICIT_STRUCTURED_GRID',
#  'VTK_EXTRACT_ALL_CLUSTERS',
#  'VTK_EXTRACT_ALL_REGIONS',
#  'VTK_EXTRACT_CELL_SEEDED_REGIONS',
#  'VTK_EXTRACT_CLOSEST_POINT_CLUSTER',
#  'VTK_EXTRACT_CLOSEST_POINT_REGION',
#  'VTK_EXTRACT_COMPONENT',
#  'VTK_EXTRACT_DETERMINANT',
#  'VTK_EXTRACT_EFFECTIVE_STRESS',
#  'VTK_EXTRACT_LARGEST_CLUSTER',
#  'VTK_EXTRACT_LARGEST_REGION',
#  'VTK_EXTRACT_POINT_SEEDED_CLUSTERS',
#  'VTK_EXTRACT_POINT_SEEDED_REGIONS',
#  'VTK_EXTRACT_SPECIFIED_CLUSTERS',
#  'VTK_EXTRACT_SPECIFIED_REGIONS',
#  'VTK_FILE_BYTE_ORDER_BIG_ENDIAN',
#  'VTK_FILE_BYTE_ORDER_LITTLE_ENDIAN',
#  'VTK_FLAT',
#  'VTK_FLOAT',
#  'VTK_FLOAT_MAX',
#  'VTK_FLOAT_MIN',
#  'VTK_FONT_FILE',
#  'VTK_FOREGROUND_LOCATION',
#  'VTK_GENERIC_DATA_SET',
#  'VTK_GET_ARRAY_BY_ID',
#  'VTK_GET_ARRAY_BY_NAME',
#  'VTK_GOURAUD',
#  'VTK_GRAPH',
#  'VTK_GRID_CUBIC',
#  'VTK_GRID_LINEAR',
#  'VTK_GRID_NEAREST',
#  'VTK_HAMMING_WINDOW',
#  'VTK_HANN_WINDOW',
#  'VTK_HEXAGONAL_PRISM',
#  'VTK_HEXAHEDRON',
#  'VTK_HIERARCHICAL_BOX_DATA_SET',
#  'VTK_HIERARCHICAL_DATA_SET',
#  'VTK_HIGHER_ORDER_EDGE',
#  'VTK_HIGHER_ORDER_HEXAHEDRON',
#  'VTK_HIGHER_ORDER_POLYGON',
#  'VTK_HIGHER_ORDER_PYRAMID',
#  'VTK_HIGHER_ORDER_QUAD',
#  'VTK_HIGHER_ORDER_TETRAHEDRON',
#  'VTK_HIGHER_ORDER_TRIANGLE',
#  'VTK_HIGHER_ORDER_WEDGE',
#  'VTK_HOOKEDARROW_GLYPH',
#  'VTK_HYPER_OCTREE',
#  'VTK_HYPER_TREE_GRID',
#  'VTK_ICON_GRAVITY_BOTTOM_CENTER',
#  'VTK_ICON_GRAVITY_BOTTOM_LEFT',
#  'VTK_ICON_GRAVITY_BOTTOM_RIGHT',
#  'VTK_ICON_GRAVITY_CENTER_CENTER',
#  'VTK_ICON_GRAVITY_CENTER_LEFT',
#  'VTK_ICON_GRAVITY_CENTER_RIGHT',
#  'VTK_ICON_GRAVITY_TOP_CENTER',
#  'VTK_ICON_GRAVITY_TOP_LEFT',
#  'VTK_ICON_GRAVITY_TOP_RIGHT',
#  'VTK_ICON_SCALING_OFF',
#  'VTK_ICON_SCALING_USE_SCALING_ARRAY',
#  'VTK_ICP_MODE_AV',
#  'VTK_ICP_MODE_RMS',
#  'VTK_ID_MAX',
#  'VTK_ID_MIN',
#  'VTK_ID_TYPE',
#  'VTK_ID_TYPE_IMPL',
#  'VTK_ID_TYPE_PRId',
#  'VTK_IMAGE_BLEND_MODE_COMPOUND',
#  'VTK_IMAGE_BLEND_MODE_NORMAL',
#  'VTK_IMAGE_BORDER_CLAMP',
#  'VTK_IMAGE_BORDER_MIRROR',
#  'VTK_IMAGE_BORDER_REPEAT',
#  'VTK_IMAGE_BSPLINE_DEGREE_MAX',
#  'VTK_IMAGE_DATA',
#  'VTK_IMAGE_NON_MAXIMUM_SUPPRESSION_MAGNITUDE_INPUT',
#  'VTK_IMAGE_NON_MAXIMUM_SUPPRESSION_VECTOR_INPUT',
#  'VTK_IMAGE_PLANE_WIDGET_MAX_TEXTBUFF',
#  'VTK_IMAGE_SLAB_MAX',
#  'VTK_IMAGE_SLAB_MEAN',
#  'VTK_IMAGE_SLAB_MIN',
#  'VTK_IMAGE_SLAB_SUM',
#  'VTK_INDEXING_BY_SCALAR',
#  'VTK_INDEXING_BY_VECTOR',
#  'VTK_INDEXING_OFF',
#  'VTK_INSIDE_CLOSEST_POINT_REGION',
#  'VTK_INSIDE_LARGEST_REGION',
#  'VTK_INSIDE_SMALLEST_REGION',
#  'VTK_INT',
#  'VTK_INTEGRATE_BACKWARD',
#  'VTK_INTEGRATE_BOTH_DIRECTIONS',
#  'VTK_INTEGRATE_FORWARD',
#  'VTK_INTEGRATE_MAJOR_EIGENVECTOR',
#  'VTK_INTEGRATE_MEDIUM_EIGENVECTOR',
#  'VTK_INTEGRATE_MINOR_EIGENVECTOR',
#  'VTK_INT_MAX',
#  'VTK_INT_MIN',
#  'VTK_INVERT',
#  'VTK_ITERATION_MODE_DIRECT_NB',
#  'VTK_ITERATION_MODE_MAX',
#  'VTK_ITW_PROJECTION_XY',
#  'VTK_ITW_PROJECTION_XZ',
#  'VTK_ITW_PROJECTION_YZ',
#  'VTK_ITW_SNAP_CELLS',
#  'VTK_ITW_SNAP_POINTS',
#  'VTK_IV_COLUMN',
#  'VTK_IV_ROW',
#  'VTK_KAISER_WINDOW',
#  'VTK_LABEL_FIELD_DATA',
#  'VTK_LABEL_IDS',
#  'VTK_LABEL_NORMALS',
#  'VTK_LABEL_SCALARS',
#  'VTK_LABEL_TCOORDS',
#  'VTK_LABEL_TENSORS',
#  'VTK_LABEL_VECTORS',
#  'VTK_LAGRANGE_CURVE',
#  'VTK_LAGRANGE_HEXAHEDRON',
#  'VTK_LAGRANGE_PYRAMID',
#  'VTK_LAGRANGE_QUADRILATERAL',
#  'VTK_LAGRANGE_TETRAHEDRON',
#  'VTK_LAGRANGE_TRIANGLE',
#  'VTK_LAGRANGE_WEDGE',
#  'VTK_LANCZOS_WINDOW',
#  'VTK_LANDMARK_AFFINE',
#  'VTK_LANDMARK_RIGIDBODY',
#  'VTK_LANDMARK_SIMILARITY',
#  'VTK_LIGHT_TYPE_CAMERA_LIGHT',
#  'VTK_LIGHT_TYPE_HEADLIGHT',
#  'VTK_LIGHT_TYPE_SCENE_LIGHT',
#  'VTK_LINE',
#  'VTK_LINEAR_INTERPOLATION',
#  'VTK_LINEAR_RESLICE',
#  'VTK_LITTLE_ENDIAN',
#  'VTK_LOG',
#  'VTK_LONG',
#  'VTK_LONG_LONG',
#  'VTK_LONG_LONG_MAX',
#  'VTK_LONG_LONG_MIN',
#  'VTK_LONG_MAX',
#  'VTK_LONG_MIN',
#  'VTK_LOOP_CLOSURE_ALL',
#  'VTK_LOOP_CLOSURE_BOUNDARY',
#  'VTK_LOOP_CLOSURE_OFF',
#  'VTK_LSDYNA_BADFILE',
#  'VTK_LUMINANCE',
#  'VTK_LUMINANCE_ALPHA',
#  'VTK_MAJOR_VERSION',
#  'VTK_MARKER_CIRCLE',
#  'VTK_MARKER_CROSS',
#  'VTK_MARKER_DIAMOND',
#  'VTK_MARKER_NONE',
#  'VTK_MARKER_PLUS',
#  'VTK_MARKER_SQUARE',
#  'VTK_MARKER_UNKNOWN',
#  'VTK_MATERIALMODE_AMBIENT',
#  'VTK_MATERIALMODE_AMBIENT_AND_DIFFUSE',
#  'VTK_MATERIALMODE_DEFAULT',
#  'VTK_MATERIALMODE_DIFFUSE',
#  'VTK_MAX',
#  'VTK_MAXIMUM_NUMBER_OF_POLAR_AXIS_TICKS',
#  'VTK_MAXIMUM_NUMBER_OF_RADIAL_AXES',
#  'VTK_MAXIMUM_RATIO',
#  'VTK_MAXPATH',
#  'VTK_MAX_CIRCLE_RESOLUTION',
#  'VTK_MAX_CYL_RESOLUTION',
#  'VTK_MAX_LEVEL',
#  'VTK_MAX_SHADING_TABLES',
#  'VTK_MAX_SPHERE_RESOLUTION',
#  'VTK_MAX_SPHERE_TREE_LEVELS',
#  'VTK_MAX_SPHERE_TREE_RESOLUTION',
#  'VTK_MAX_SUPERQUADRIC_RESOLUTION',
#  'VTK_MAX_THREADS',
#  'VTK_MAX_VRCOMP',
#  'VTK_MIN',
#  'VTK_MINOR_VERSION',
#  'VTK_MIN_SUPERQUADRIC_ROUNDNESS',
#  'VTK_MIN_SUPERQUADRIC_THICKNESS',
#  'VTK_MOLECULE',
#  'VTK_MTIME_MAX',
#  'VTK_MTIME_MIN',
#  'VTK_MTIME_TYPE_IMPL',
#  'VTK_MULTIBLOCK_DATA_SET',
#  'VTK_MULTIGROUP_DATA_SET',
#  'VTK_MULTIPIECE_DATA_SET',
#  'VTK_MULTIPLY',
#  'VTK_MULTIPLYBYK',
#  'VTK_NAND',
#  'VTK_NEAREST_INTERPOLATION',
#  'VTK_NEAREST_RESLICE',
#  'VTK_NODE_OVERLAP',
#  'VTK_NON_OVERLAPPING_AMR',
#  'VTK_NOP',
#  'VTK_NOR',
#  'VTK_NORMALIZED_DISPLAY',
#  'VTK_NORMALIZED_VIEWPORT',
#  'VTK_NORMAL_EXTRUSION',
#  'VTK_NOT',
#  'VTK_NO_GLYPH',
#  'VTK_NO_OVERLAP',
#  'VTK_NUMBER_OF_CELL_TYPES',
#  'VTK_NUTTALL_WINDOW',
#  'VTK_OBJECT',
#  'VTK_OK',
#  'VTK_OPAQUE',
#  'VTK_OR',
#  'VTK_ORIENT_HORIZONTAL',
#  'VTK_ORIENT_VERTICAL',
#  'VTK_OUTPUT_BOTH',
#  'VTK_OUTPUT_POLYGONS',
#  'VTK_OUTPUT_POLYLINES',
#  'VTK_OVERLAPPING_AMR',
#  'VTK_PARAMETRIC_CURVE',
#  'VTK_PARAMETRIC_HEX_REGION',
#  'VTK_PARAMETRIC_QUAD_SURFACE',
#  'VTK_PARAMETRIC_SURFACE',
#  'VTK_PARAMETRIC_TETRA_REGION',
#  'VTK_PARAMETRIC_TRI_SURFACE',
#  'VTK_PARSER_ABSOLUTE_VALUE',
#  'VTK_PARSER_ADD',
#  'VTK_PARSER_AND',
#  'VTK_PARSER_ARCCOSINE',
#  'VTK_PARSER_ARCSINE',
#  'VTK_PARSER_ARCTANGENT',
#  'VTK_PARSER_BEGIN_VARIABLES',
#  'VTK_PARSER_CEILING',
#  'VTK_PARSER_COSINE',
#  'VTK_PARSER_CROSS',
#  'VTK_PARSER_DIVIDE',
#  'VTK_PARSER_DOT_PRODUCT',
#  'VTK_PARSER_EQUAL_TO',
#  'VTK_PARSER_ERROR_RESULT',
#  'VTK_PARSER_EXPONENT',
#  'VTK_PARSER_FLOOR',
#  'VTK_PARSER_GREATER_THAN',
#  'VTK_PARSER_HYPERBOLIC_COSINE',
#  'VTK_PARSER_HYPERBOLIC_SINE',
#  'VTK_PARSER_HYPERBOLIC_TANGENT',
#  'VTK_PARSER_IF',
#  'VTK_PARSER_IHAT',
#  'VTK_PARSER_IMMEDIATE',
#  'VTK_PARSER_JHAT',
#  'VTK_PARSER_KHAT',
#  'VTK_PARSER_LESS_THAN',
#  'VTK_PARSER_LOGARITHM',
#  'VTK_PARSER_LOGARITHM10',
#  'VTK_PARSER_LOGARITHME',
#  'VTK_PARSER_MAGNITUDE',
#  'VTK_PARSER_MAX',
#  'VTK_PARSER_MIN',
#  'VTK_PARSER_MULTIPLY',
#  'VTK_PARSER_NORMALIZE',
#  'VTK_PARSER_OR',
#  'VTK_PARSER_POWER',
#  'VTK_PARSER_SCALAR_TIMES_VECTOR',
#  'VTK_PARSER_SIGN',
#  'VTK_PARSER_SINE',
#  'VTK_PARSER_SQUARE_ROOT',
#  'VTK_PARSER_SUBTRACT',
#  'VTK_PARSER_TANGENT',
#  'VTK_PARSER_UNARY_MINUS',
#  'VTK_PARSER_UNARY_PLUS',
#  'VTK_PARSER_VECTOR_ADD',
#  'VTK_PARSER_VECTOR_IF',
#  'VTK_PARSER_VECTOR_OVER_SCALAR',
#  'VTK_PARSER_VECTOR_SUBTRACT',
#  'VTK_PARSER_VECTOR_TIMES_SCALAR',
#  'VTK_PARSER_VECTOR_UNARY_MINUS',
#  'VTK_PARSER_VECTOR_UNARY_PLUS',
#  'VTK_PARTIAL_OVERLAP',
#  'VTK_PARTITIONED_DATA_SET',
#  'VTK_PARTITIONED_DATA_SET_COLLECTION',
#  'VTK_PATH',
#  'VTK_PBR',
#  'VTK_PENTAGONAL_PRISM',
#  'VTK_PERIODIC_ARRAY_AXIS_X',
#  'VTK_PERIODIC_ARRAY_AXIS_Y',
#  'VTK_PERIODIC_ARRAY_AXIS_Z',
#  'VTK_PHONG',
#  'VTK_PIECES_EXTENT',
#  'VTK_PIECEWISE_FUNCTION',
#  'VTK_PISTON_DATA_OBJECT',
#  'VTK_PIXEL',
#  'VTK_PLANE_OFF',
#  'VTK_PLANE_OUTLINE',
#  'VTK_PLANE_SURFACE',
#  'VTK_PLANE_WIREFRAME',
#  'VTK_PLOT_FIELD_DATA',
#  'VTK_PLOT_NORMALS',
#  'VTK_PLOT_SCALARS',
#  'VTK_PLOT_TCOORDS',
#  'VTK_PLOT_TENSORS',
#  'VTK_PLOT_VECTORS',
#  'VTK_POINTS',
#  'VTK_POINT_DATA',
#  'VTK_POINT_DATA_FIELD',
#  'VTK_POINT_EXTRUSION',
#  'VTK_POINT_SET',
#  'VTK_POINT_SHELL',
#  'VTK_POINT_UNIFORM',
#  'VTK_POLAR_ARC_RESOLUTION_PER_DEG',
#  'VTK_POLYGON',
#  'VTK_POLYHEDRON',
#  'VTK_POLY_DATA',
#  'VTK_POLY_LINE',
#  'VTK_POLY_VERTEX',
#  'VTK_POSE',
#  'VTK_PROJECTED_TEXTURE_USE_PINHOLE',
#  'VTK_PROJECTED_TEXTURE_USE_TWO_MIRRORS',
#  'VTK_PROJECTION_OBLIQUE',
#  'VTK_PROJECTION_XY',
#  'VTK_PROJECTION_XZ',
#  'VTK_PROJECTION_YZ',
#  'VTK_PYRAMID',
#  'VTK_QUAD',
#  'VTK_QUADRATIC_EDGE',
#  'VTK_QUADRATIC_HEXAHEDRON',
#  'VTK_QUADRATIC_LINEAR_QUAD',
#  'VTK_QUADRATIC_LINEAR_WEDGE',
#  'VTK_QUADRATIC_POLYGON',
#  'VTK_QUADRATIC_PYRAMID',
#  'VTK_QUADRATIC_QUAD',
#  'VTK_QUADRATIC_TETRA',
#  'VTK_QUADRATIC_TRIANGLE',
#  'VTK_QUADRATIC_WEDGE',
#  'VTK_QUALITY_AREA',
#  'VTK_QUALITY_ASPECT_BETA',
#  'VTK_QUALITY_ASPECT_FROBENIUS',
#  'VTK_QUALITY_ASPECT_GAMMA',
#  'VTK_QUALITY_ASPECT_RATIO',
#  'VTK_QUALITY_COLLAPSE_RATIO',
#  'VTK_QUALITY_CONDITION',
#  'VTK_QUALITY_DIAGONAL',
#  'VTK_QUALITY_DIMENSION',
#  'VTK_QUALITY_DISTORTION',
#  'VTK_QUALITY_EDGE_RATIO',
#  'VTK_QUALITY_JACOBIAN',
#  'VTK_QUALITY_MAX_ANGLE',
#  'VTK_QUALITY_MAX_ASPECT_FROBENIUS',
#  'VTK_QUALITY_MAX_EDGE_RATIO',
#  'VTK_QUALITY_MED_ASPECT_FROBENIUS',
#  'VTK_QUALITY_MIN_ANGLE',
#  'VTK_QUALITY_ODDY',
#  'VTK_QUALITY_RADIUS_RATIO',
#  'VTK_QUALITY_RELATIVE_SIZE_SQUARED',
#  'VTK_QUALITY_SCALED_JACOBIAN',
#  'VTK_QUALITY_SHAPE',
#  'VTK_QUALITY_SHAPE_AND_SIZE',
#  'VTK_QUALITY_SHEAR',
#  'VTK_QUALITY_SHEAR_AND_SIZE',
#  'VTK_QUALITY_SKEW',
#  'VTK_QUALITY_STRETCH',
#  'VTK_QUALITY_TAPER',
#  'VTK_QUALITY_VOLUME',
#  'VTK_QUALITY_WARPAGE',
#  'VTK_RAMP_LINEAR',
#  'VTK_RAMP_SCURVE',
#  'VTK_RAMP_SQRT',
#  'VTK_RBF_CUSTOM',
#  'VTK_RBF_R',
#  'VTK_RBF_R2LOGR',
#  'VTK_RECTILINEAR_GRID',
#  'VTK_REEB_GRAPH',
#  'VTK_REPLACECBYK',
#  'VTK_RESLICE_CUBIC',
#  'VTK_RESLICE_CURSOR_REPRESENTATION_MAX_TEXTBUFF',
#  'VTK_RESLICE_LINEAR',
#  'VTK_RESLICE_NEAREST',
#  'VTK_RESOLVE_OFF',
#  'VTK_RESOLVE_POLYGON_OFFSET',
#  'VTK_RESOLVE_SHIFT_ZBUFFER',
#  'VTK_RGB',
#  'VTK_RGBA',
#  'VTK_ROTATION_MODE_ARRAY_VALUE',
#  'VTK_ROTATION_MODE_DIRECT_ANGLE',
#  'VTK_RULED_MODE_POINT_WALK',
#  'VTK_RULED_MODE_RESAMPLE',
#  'VTK_SCALAR_MODE_DEFAULT',
#  'VTK_SCALAR_MODE_INDEX',
#  'VTK_SCALAR_MODE_USE_CELL_DATA',
#  'VTK_SCALAR_MODE_USE_CELL_FIELD_DATA',
#  'VTK_SCALAR_MODE_USE_FIELD_DATA',
#  'VTK_SCALAR_MODE_USE_POINT_DATA',
#  'VTK_SCALAR_MODE_USE_POINT_FIELD_DATA',
#  'VTK_SCALAR_MODE_VALUE',
#  'VTK_SCALE_BY_SCALAR',
#  'VTK_SCALE_BY_VECTOR',
#  'VTK_SCALE_BY_VECTORCOMPONENTS',
#  'VTK_SCALE_LINEAR',
#  'VTK_SCALE_LOG10',
#  'VTK_SELECTION',
#  'VTK_SET_TRANSFORM_PLANE',
#  'VTK_SHORT',
#  'VTK_SHORT_MAX',
#  'VTK_SHORT_MIN',
#  'VTK_SIGNED_CHAR',
#  'VTK_SIGNED_CHAR_MAX',
#  'VTK_SIGNED_CHAR_MIN',
#  'VTK_SIN',
#  'VTK_SINC_KERNEL_SIZE_MAX',
#  'VTK_SINGLE_POINT',
#  'VTK_SIZEOF_CHAR',
#  'VTK_SIZEOF_DOUBLE',
#  'VTK_SIZEOF_FLOAT',
#  'VTK_SIZEOF_ID_TYPE',
#  'VTK_SIZEOF_INT',
#  'VTK_SIZEOF_LONG',
#  'VTK_SIZEOF_LONG_LONG',
#  'VTK_SIZEOF_SHORT',
#  'VTK_SIZEOF_VOID_P',
#  'VTK_SKIP_RETURN_CODE',
#  'VTK_SMP_BACKEND',
#  'VTK_SOLID_CUBE',
#  'VTK_SOLID_DODECAHEDRON',
#  'VTK_SOLID_ICOSAHEDRON',
#  'VTK_SOLID_OCTAHEDRON',
#  'VTK_SOLID_TETRAHEDRON',
#  'VTK_SORT_BY_CELL',
#  'VTK_SORT_BY_VALUE',
#  'VTK_SOURCE_VERSION',
#  'VTK_SPHERE_OFF',
#  'VTK_SPHERE_SURFACE',
#  'VTK_SPHERE_TREE_LEVELS',
#  'VTK_SPHERE_TREE_LINE',
#  'VTK_SPHERE_TREE_PLANE',
#  'VTK_SPHERE_TREE_POINT',
#  'VTK_SPHERE_WIREFRAME',
#  'VTK_SQL_ALLBACKENDS',
#  'VTK_SQL_DEFAULT_COLUMN_SIZE',
#  'VTK_SQL_FEATURE_BATCH_OPERATIONS',
#  'VTK_SQL_FEATURE_BLOB',
#  'VTK_SQL_FEATURE_LAST_INSERT_ID',
#  'VTK_SQL_FEATURE_NAMED_PLACEHOLDERS',
#  'VTK_SQL_FEATURE_POSITIONAL_PLACEHOLDERS',
#  'VTK_SQL_FEATURE_PREPARED_QUERIES',
#  'VTK_SQL_FEATURE_QUERY_SIZE',
#  'VTK_SQL_FEATURE_TRANSACTIONS',
#  'VTK_SQL_FEATURE_TRIGGERS',
#  'VTK_SQL_FEATURE_UNICODE',
#  'VTK_SQL_MYSQL',
#  'VTK_SQL_POSTGRESQL',
#  'VTK_SQL_SQLITE',
#  'VTK_SQR',
#  'VTK_SQRT',
#  'VTK_SQUARE_GLYPH',
#  'VTK_STEREO_ANAGLYPH',
#  'VTK_STEREO_CHECKERBOARD',
#  'VTK_STEREO_CRYSTAL_EYES',
#  'VTK_STEREO_DRESDEN',
#  'VTK_STEREO_EMULATE',
#  'VTK_STEREO_FAKE',
#  'VTK_STEREO_INTERLACED',
#  'VTK_STEREO_LEFT',
#  'VTK_STEREO_RED_BLUE',
#  'VTK_STEREO_RIGHT',
#  'VTK_STEREO_SPLITVIEWPORT_HORIZONTAL',
#  'VTK_STRING',
#  'VTK_STRUCTURED_GRID',
#  'VTK_STRUCTURED_POINTS',
#  'VTK_STYLE_PIXELIZE',
#  'VTK_STYLE_POLYGONALIZE',
#  'VTK_STYLE_RUN_LENGTH',
#  'VTK_SUBDIVIDE_LENGTH',
#  'VTK_SUBDIVIDE_SPECIFIED',
#  'VTK_SUBTRACT',
#  'VTK_SURFACE',
#  'VTK_TABLE',
#  'VTK_TCOORDS_FROM_LENGTH',
#  'VTK_TCOORDS_FROM_NORMALIZED_LENGTH',
#  'VTK_TCOORDS_FROM_SCALARS',
#  'VTK_TCOORDS_OFF',
#  'VTK_TEMPORAL_DATA_SET',
#  'VTK_TENSOR_MODE_COMPUTE_GRADIENT',
#  'VTK_TENSOR_MODE_COMPUTE_GREEN_LAGRANGE_STRAIN',
#  'VTK_TENSOR_MODE_COMPUTE_STRAIN',
#  'VTK_TENSOR_MODE_PASS_TENSORS',
#  'VTK_TETRA',
#  'VTK_TEXTURECOORDS_TEXTUREUV',
#  'VTK_TEXTURECOORDS_UV',
#  'VTK_TEXTURE_QUALITY_16BIT',
#  'VTK_TEXTURE_QUALITY_32BIT',
#  'VTK_TEXTURE_QUALITY_DEFAULT',
#  'VTK_TEXTURE_STYLE_FIT_IMAGE',
#  'VTK_TEXTURE_STYLE_PROPORTIONAL',
#  'VTK_TEXT_BOTTOM',
#  'VTK_TEXT_CENTERED',
#  'VTK_TEXT_GLOBAL_ANTIALIASING_ALL',
#  'VTK_TEXT_GLOBAL_ANTIALIASING_NONE',
#  'VTK_TEXT_GLOBAL_ANTIALIASING_SOME',
#  'VTK_TEXT_LEFT',
#  'VTK_TEXT_RIGHT',
#  'VTK_TEXT_TOP',
#  'VTK_THICKARROW_GLYPH',
#  'VTK_THICKCROSS_GLYPH',
#  'VTK_THREAD_RETURN_VALUE',
#  'VTK_TIMES',
#  'VTK_TIME_EXTENT',
#  'VTK_TOL',
#  'VTK_TREE',
#  'VTK_TRIANGLE',
#  'VTK_TRIANGLE_GLYPH',
#  'VTK_TRIANGLE_STRIP',
#  'VTK_TRIQUADRATIC_HEXAHEDRON',
#  'VTK_TYPE_CHAR_IS_SIGNED',
#  'VTK_TYPE_FLOAT32',
#  'VTK_TYPE_FLOAT64',
#  'VTK_TYPE_INT16',
#  'VTK_TYPE_INT16_MAX',
#  'VTK_TYPE_INT16_MIN',
#  'VTK_TYPE_INT32',
#  'VTK_TYPE_INT32_MAX',
#  'VTK_TYPE_INT32_MIN',
#  'VTK_TYPE_INT64',
#  'VTK_TYPE_INT64_MAX',
#  'VTK_TYPE_INT64_MIN',
#  'VTK_TYPE_INT8',
#  'VTK_TYPE_INT8_MAX',
#  'VTK_TYPE_INT8_MIN',
#  'VTK_TYPE_LONG_LONG_FORMAT',
#  'VTK_TYPE_UINT16',
#  'VTK_TYPE_UINT16_MAX',
#  'VTK_TYPE_UINT16_MIN',
#  'VTK_TYPE_UINT32',
#  'VTK_TYPE_UINT32_MAX',
#  'VTK_TYPE_UINT32_MIN',
#  'VTK_TYPE_UINT64',
#  'VTK_TYPE_UINT64_MAX',
#  'VTK_TYPE_UINT64_MIN',
#  'VTK_TYPE_UINT8',
#  'VTK_TYPE_UINT8_MAX',
#  'VTK_TYPE_UINT8_MIN',
#  'VTK_UNCHANGED',
#  'VTK_UNDIRECTED_GRAPH',
#  'VTK_UNICAM_BUTTON_LEFT',
#  'VTK_UNICAM_BUTTON_MIDDLE',
#  'VTK_UNICAM_BUTTON_RIGHT',
#  'VTK_UNICAM_CAM_INT_CHOOSE',
#  'VTK_UNICAM_CAM_INT_DOLLY',
#  'VTK_UNICAM_CAM_INT_PAN',
#  'VTK_UNICAM_CAM_INT_ROT',
#  'VTK_UNICAM_NONE',
#  'VTK_UNICODE_STRING',
#  'VTK_UNIFORM_GRID',
#  'VTK_UNIFORM_GRID_AMR',
#  'VTK_UNIFORM_HYPER_TREE_GRID',
#  'VTK_UNKNOWN_FONT',
#  'VTK_UNSIGNED_CHAR',
#  'VTK_UNSIGNED_CHAR_MAX',
#  'VTK_UNSIGNED_CHAR_MIN',
#  'VTK_UNSIGNED_INT',
#  'VTK_UNSIGNED_INT_MAX',
#  'VTK_UNSIGNED_INT_MIN',
#  'VTK_UNSIGNED_LONG',
#  'VTK_UNSIGNED_LONG_LONG',
#  'VTK_UNSIGNED_LONG_LONG_MAX',
#  'VTK_UNSIGNED_LONG_LONG_MIN',
#  'VTK_UNSIGNED_LONG_MAX',
#  'VTK_UNSIGNED_LONG_MIN',
#  'VTK_UNSIGNED_SHORT',
#  'VTK_UNSIGNED_SHORT_MAX',
#  'VTK_UNSIGNED_SHORT_MIN',
#  'VTK_UNSIGNED___INT64',
#  'VTK_UNSTRUCTURED_GRID',
#  'VTK_UNSTRUCTURED_GRID_BASE',
#  'VTK_UPDATE_EXTENT_COMBINE',
#  'VTK_UPDATE_EXTENT_REPLACE',
#  'VTK_USERDEFINED',
#  'VTK_USE_FLOAT32',
#  'VTK_USE_FLOAT64',
#  'VTK_USE_INT16',
#  'VTK_USE_INT32',
#  'VTK_USE_INT64',
#  'VTK_USE_INT8',
#  'VTK_USE_NORMAL',
#  'VTK_USE_UINT16',
#  'VTK_USE_UINT32',
#  'VTK_USE_UINT64',
#  'VTK_USE_UINT8',
#  'VTK_USE_VECTOR',
#  'VTK_VARIANT',
#  'VTK_VARY_RADIUS_BY_ABSOLUTE_SCALAR',
#  'VTK_VARY_RADIUS_BY_SCALAR',
#  'VTK_VARY_RADIUS_BY_VECTOR',
#  'VTK_VARY_RADIUS_OFF',
#  'VTK_VECTOR_EXTRUSION',
#  'VTK_VECTOR_MODE_COMPUTE_GRADIENT',
#  'VTK_VECTOR_MODE_COMPUTE_VORTICITY',
#  'VTK_VECTOR_MODE_PASS_VECTORS',
#  'VTK_VECTOR_ROTATION_OFF',
#  'VTK_VERSION',
#  'VTK_VERSION_NUMBER',
#  'VTK_VERTEX',
#  'VTK_VERTEX_GLYPH',
#  'VTK_VIEW',
#  'VTK_VIEWPORT',
#  'VTK_VOID',
#  'VTK_VOXEL',
#  'VTK_VOXEL_MODE',
#  'VTK_VOXEL_TO_12_TET',
#  'VTK_VOXEL_TO_5_AND_12_TET',
#  'VTK_VOXEL_TO_5_TET',
#  'VTK_VOXEL_TO_6_TET',
#  'VTK_WEDGE',
#  'VTK_WIPE_HORIZONTAL',
#  'VTK_WIPE_LOWER_LEFT',
#  'VTK_WIPE_LOWER_RIGHT',
#  'VTK_WIPE_QUAD',
#  'VTK_WIPE_UPPER_LEFT',
#  'VTK_WIPE_UPPER_RIGHT',
#  'VTK_WIPE_VERTICAL',
#  'VTK_WIREFRAME',
#  'VTK_WORLD',
#  'VTK_XOR',
#  'VTK_XYPLOT_ARC_LENGTH',
#  'VTK_XYPLOT_COLUMN',
#  'VTK_XYPLOT_INDEX',
#  'VTK_XYPLOT_NORMALIZED_ARC_LENGTH',
#  'VTK_XYPLOT_ROW',
#  'VTK_XYPLOT_VALUE',
#  'VTK_XYPLOT_Y_AXIS_HCENTER',
#  'VTK_XYPLOT_Y_AXIS_TOP',
#  'VTK_XYPLOT_Y_AXIS_VCENTER',
#  'VTK_XYZ_GRID',
#  'VTK_XY_PLANE',
#  'VTK_XZ_PLANE',
#  'VTK_X_LINE',
#  'VTK_YZ_PLANE',
#  'VTK_Y_LINE',
#  'VTK_ZBUFFER',
#  'VTK_Z_LINE',
#  'VTK___INT64',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'absolute_import',
#  'buffer_shared',
#  'calldata_type',
#  'mutable',
#  'reference',
#  'sys',
#  'vtk3DLinearGridCrinkleExtractor',
#  'vtk3DLinearGridPlaneCutter',
#  'vtk3DSImporter',
#  'vtk3DWidget',
#  'vtkAMRBaseParticlesReader',
#  'vtkAMRBaseReader',
#  'vtkAMRBox',
#  'vtkAMRCutPlane',
#  'vtkAMRDataInternals',
#  'vtkAMRDataSetCache',
#  'vtkAMREnzoParticlesReader',
#  'vtkAMREnzoReader',
#  'vtkAMRFlashParticlesReader',
#  'vtkAMRFlashReader',
#  'vtkAMRGaussianPulseSource',
#  'vtkAMRInformation',
#  'vtkAMRInterpolatedVelocityField',
#  'vtkAMRResampleFilter',
#  'vtkAMRSliceFilter',
#  'vtkAMRToMultiBlockFilter',
#  'vtkAMRUtilities',
#  'vtkAMReXGridReader',
#  'vtkAMReXParticlesReader',
#  'vtkASCIITextCodec',
#  'vtkAVSucdReader',
#  'vtkAbstractArray',
#  'vtkAbstractCellLinks',
#  'vtkAbstractCellLocator',
#  'vtkAbstractContextBufferId',
#  'vtkAbstractContextItem',
#  'vtkAbstractElectronicData',
#  'vtkAbstractGridConnectivity',
#  'vtkAbstractImageInterpolator',
#  'vtkAbstractInteractionDevice',
#  'vtkAbstractInterpolatedVelocityField',
#  'vtkAbstractMapper',
#  'vtkAbstractMapper3D',
#  'vtkAbstractParticleWriter',
#  'vtkAbstractPicker',
#  'vtkAbstractPointLocator',
#  'vtkAbstractPolyDataReader',
#  'vtkAbstractPolygonalHandleRepresentation3D',
#  'vtkAbstractPropPicker',
#  'vtkAbstractRenderDevice',
#  'vtkAbstractTransform',
#  'vtkAbstractVolumeMapper',
#  'vtkAbstractWidget',
#  'vtkActor',
#  'vtkActor2D',
#  'vtkActor2DCollection',
#  'vtkActorCollection',
#  'vtkActorNode',
#  'vtkAdaptiveDataSetSurfaceFilter',
#  'vtkAdaptiveSubdivisionFilter',
#  'vtkAdaptiveTemporalInterpolator',
#  'vtkAddMembershipArray',
#  'vtkAdjacencyMatrixToEdgeTable',
#  'vtkAdjacentVertexIterator',
#  'vtkAffineRepresentation',
#  'vtkAffineRepresentation2D',
#  'vtkAffineWidget',
#  'vtkAggregateDataSetFilter',
#  'vtkAlgorithm',
#  'vtkAlgorithmOutput',
#  'vtkAmoebaMinimizer',
#  'vtkAngleRepresentation',
#  'vtkAngleRepresentation2D',
#  'vtkAngleRepresentation3D',
#  'vtkAngleWidget',
#  'vtkAngularPeriodicFilter',
#  'vtkAnimationCue',
#  'vtkAnimationScene',
#  'vtkAnnotatedCubeActor',
#  'vtkAnnotation',
#  'vtkAnnotationLayers',
#  'vtkAnnotationLayersAlgorithm',
#  'vtkAnnotationLink',
#  'vtkAppendArcLength',
#  'vtkAppendCompositeDataLeaves',
#  'vtkAppendDataSets',
#  'vtkAppendFilter',
#  'vtkAppendLocationAttributes',
#  'vtkAppendPoints',
#  'vtkAppendPolyData',
#  'vtkAppendSelection',
#  'vtkApplyColors',
#  'vtkApplyIcons',
#  'vtkApproximatingSubdivisionFilter',
#  'vtkArcParallelEdgeStrategy',
#  'vtkArcPlotter',
#  'vtkArcSource',
#  'vtkArchiver',
#  'vtkAreaContourSpectrumFilter',
#  'vtkAreaLayout',
#  'vtkAreaLayoutStrategy',
#  'vtkAreaPicker',
#  'vtkArray',
#  'vtkArrayCalculator',
#  'vtkArrayCoordinates',
#  'vtkArrayData',
#  'vtkArrayDataAlgorithm',
#  'vtkArrayDataReader',
#  'vtkArrayDataWriter',
#  'vtkArrayExtents',
#  'vtkArrayExtentsList',
#  'vtkArrayIterator',
#  'vtkArrayIteratorTemplate',
#  'vtkArrayIteratorTemplate_I10vtkVariantE',
#  'vtkArrayIteratorTemplate_I12vtkStdStringE',
#  'vtkArrayIteratorTemplate_I16vtkUnicodeStringE',
#  'vtkArrayIteratorTemplate_IaE',
#  'vtkArrayIteratorTemplate_IcE',
#  'vtkArrayIteratorTemplate_IdE',
#  'vtkArrayIteratorTemplate_IfE',
#  'vtkArrayIteratorTemplate_IhE',
#  'vtkArrayIteratorTemplate_IiE',
#  'vtkArrayIteratorTemplate_IjE',
#  'vtkArrayIteratorTemplate_IlE',
#  'vtkArrayIteratorTemplate_ImE',
#  'vtkArrayIteratorTemplate_IsE',
#  'vtkArrayIteratorTemplate_ItE',
#  'vtkArrayIteratorTemplate_IxE',
#  'vtkArrayIteratorTemplate_IyE',
#  'vtkArrayNorm',
#  'vtkArrayRange',
#  'vtkArrayReader',
#  'vtkArraySort',
#  'vtkArrayToTable',
#  'vtkArrayWeights',
#  'vtkArrayWriter',
#  'vtkArrowSource',
#  'vtkAssembly',
#  ...]

# %%
import vtk

from ipywidgets import Image, Output

# from IPython.display import Image
from Parser import Parser
from ipycanvas import Canvas
from typing import Dict, Callable, Tuple, List
import ipywidgets as widgets
import numpy as np
import math

MOVE_ACTION = 'move'
ZOOM_ACTION = 'zoom'
ROTATE_ACTION = 'rotate'
SELECT_ACTION = 'select'

output = Output()

def defaultColorMap(cells, variables):
    return [
        ('#004400', 'green', cells[variables['cycle_model']] == 5),
        ('brown', 'black', cells[variables['cycle_model']] == 100),
        ('#440000', 'red', cells[variables['cycle_model']] == 101)
    ]

def count(array):
    dic = {}
    for num in array:
        if not num in dic:
            dic[num] = 0
        dic[num] += 1
    return dic
    

class Interactor3D:
    def __init__(self, parser, width: int = 500, height: int = 400, colorMap = defaultColorMap):
        self._currentFrame = parser.getFrameRange()[0]
        self._canvas = Canvas(width=width, height=height)
        self._parser = parser
        self._colorMap = colorMap
        self._height = height
        self._width = width
        
        frame = parser.getFrame(self._currentFrame)
        mesh = frame.environment.mesh
        self._zoom = max((mesh.boundsX[1] - mesh.boundsX[0]) / width, (mesh.boundsY[1] - mesh.boundsY[0]) / height)
        
        self._xOffset = mesh.boundsX[0]
        self._yOffset = mesh.boundsY[0]
        self._selectedCell = None
        
        self._clicking = False
        self._dragStartX = 0
        self._dragStartY = 0
        self._actionOriginX = 0
        self._actionOriginY = 0
        
        self._canvas.on_mouse_down(self.onMouseDown)
        self._canvas.on_mouse_move(self.onMouseMove)
        self._canvas.on_mouse_up(self.onMouseUp)
        self._canvas.on_mouse_out(self.onMouseOut)
        
        self.action = MOVE_ACTION
        
        self._buttons = widgets.RadioButtons(
            options=[MOVE_ACTION, ROTATE_ACTION, ZOOM_ACTION, SELECT_ACTION],
            value=self.action,
            description='Mouse Action:',
            disabled=False,
        )
        self._buttons.observe(self.onToolChange, names='value')
        
        self._frameSelector = widgets.IntSlider(
            value=self._currentFrame,
            min=parser.getFrameRange()[0],
            max=parser.getFrameRange()[1] - 1,
            step=1,
            description='Frame:',
            disabled=False,
            continuous_update=False,
            orientation='horizontal',
            readout=True,
            readout_format='d'
        )
        self._frameSelector.observe(self.onFrameChange, names='value')
        
        self.previousFrameNumber = -1
        self.LastPickedActor = None
        self.LastPickedProperty = vtk.vtkProperty()
        
        self.renderer = vtk.vtkRenderer()
        
        self.create(frame)
        
        renderWindow = vtk.vtkRenderWindow()
        renderWindow.SetOffScreenRendering(1)
        renderWindow.AddRenderer(self.renderer)
        renderWindow.SetSize(width, height)
        renderWindow.Render()
        
        self.renderWindow = renderWindow
        
        self.selectCell(width/4,height/2)
        
        self.update()
    
    def create(self, frameNumber):
        if frameNumber == self.previousFrameNumber:
            return
        self.previousFrameNumber = frameNumber
        frame = self._parser.getFrame(self._currentFrame)
        
        self.renderer.RemoveAllViewProps()
        cells = frame.cells.data
        variables = frame.cells.variables
        x = variables["position.x"]
        y = variables["position.y"]
        z = variables["position.z"]
        r = self.radiusOfCells(cells, variables)
        for cell in range(cells.shape[1]):
            source = vtk.vtkSphereSource()

            radius = r[cell]

            source.SetRadius(radius)
            source.SetCenter(cells[x,cell], cells[y,cell], cells[z, cell])
            source.SetPhiResolution(11)
            source.SetThetaResolution(21)

            mapper = vtk.vtkPolyDataMapper()
            mapper.SetInputConnection(source.GetOutputPort())
            actor = vtk.vtkActor()
            actor.SetMapper(mapper)

            red = vtk.vtkMath.Random(.4, 1.0)
            g = vtk.vtkMath.Random(.4, 1.0)
            b = vtk.vtkMath.Random(.4, 1.0)
            actor.GetProperty().SetDiffuseColor(red, g, b)
            actor.GetProperty().SetDiffuse(.8)
            actor.GetProperty().SetSpecular(.5)
            actor.GetProperty().SetSpecularColor(1.0, 1.0, 1.0)
            actor.GetProperty().SetSpecularPower(30.0)

            self.renderer.AddActor(actor)
        
    
    def update(self):
        canvas = self._canvas
        canvas.clear()
        
        self.create(self._currentFrame)
        
        self.renderWindow.Render()
        
        windowToImageFilter = vtk.vtkWindowToImageFilter()
        windowToImageFilter.SetInput(self.renderWindow)
        windowToImageFilter.Update()

        writer = vtk.vtkPNGWriter()
        writer.SetWriteToMemory(1)
        writer.SetInputConnection(windowToImageFilter.GetOutputPort())
        writer.Write()
        
        data = memoryview(writer.GetResult()).tobytes()
        
        image = Image(value=data)
        
        canvas.draw_image(image)
            
        
        canvas.fill_style = '#A0A0A0'
        canvas.font = '10px serif'
        canvas.fill_text(f"(x: {self._xOffset}, y: {self._yOffset}, s: {self._zoom}, c: {self._selectedCell})", 10, self._height - 10)
        
    
    @output.capture()
    def onMouseDown(self, x: int, y: int):
        self._dragStartX = x
        self._dragStartY = y
        self._envActionOriginX = x * self._zoom + self._xOffset
        self._envActionOriginY = y * self._zoom + self._yOffset
        self._actionOriginX = x
        self._actionOriginY = y
        self._actionOriginZoom = self._zoom
        
        if self.action == SELECT_ACTION:
            self.selectCell(x, self._height - y)
        else:
            self._clicking = True
    
    def onMouseUp(self, x: int, y: int):
        self._clicking = False
    
    def onMouseOut(self, x: int, y: int):
        self._clicking = False
    
    @output.capture()
    def onMouseMove(self, x: int, y: int):
        if self._clicking:
            if self.action == MOVE_ACTION:
                self.pan(x, y)
            elif self.action == ZOOM_ACTION:
                self.renderer.GetActiveCamera().Zoom(1 + (self._actionOriginY - y) / 100)
            elif self.action == ROTATE_ACTION:
                self.rotate(x, y)
                
            self._dragStartX = x
            self._dragStartY = y
            self.update()
    
    def pan(self, x: float, y: float):
        # from https://compucell3d.org/BinDoc/cc3d_binaries/dependencies/windows/MinGW/dependencies_qt_4.8.4_pyqt_4.9.6_vtk_5.10.1_python27/Player/vtk/wx/wxVTKRenderWindow.py
        renderer = self.renderer
        camera = renderer.GetActiveCamera()
        (pPoint0,pPoint1,pPoint2) = camera.GetPosition()
        (fPoint0,fPoint1,fPoint2) = camera.GetFocalPoint()

        renderer.SetWorldPoint(fPoint0,fPoint1,fPoint2,1.0)
        renderer.WorldToDisplay()
        # Convert world point coordinates to display coordinates
        dPoint = renderer.GetDisplayPoint()
        focalDepth = dPoint[2]

        aPoint0 = self._width / 2 + (x - self._dragStartX)
        aPoint1 = self._height / 2 - (y - self._dragStartY)

        renderer.SetDisplayPoint(aPoint0,aPoint1,focalDepth)
        renderer.DisplayToWorld()

        (rPoint0,rPoint1,rPoint2,rPoint3) = renderer.GetWorldPoint()
        if (rPoint3 != 0.0):
            rPoint0 = rPoint0/rPoint3
            rPoint1 = rPoint1/rPoint3
            rPoint2 = rPoint2/rPoint3

        camera.SetFocalPoint((fPoint0 - rPoint0) + fPoint0,
                             (fPoint1 - rPoint1) + fPoint1,
                             (fPoint2 - rPoint2) + fPoint2)

        camera.SetPosition((fPoint0 - rPoint0) + pPoint0,
                           (fPoint1 - rPoint1) + pPoint1,
                           (fPoint2 - rPoint2) + pPoint2)
        
    def rotate(self, x: float, y: float):
        # from https://compucell3d.org/BinDoc/cc3d_binaries/dependencies/windows/MinGW/dependencies_qt_4.8.4_pyqt_4.9.6_vtk_5.10.1_python27/Player/vtk/wx/wxVTKRenderWindow.py
        renderer = self.renderer
        camera = renderer.GetActiveCamera()
        camera.Azimuth(self._dragStartX - x)
        camera.Elevation(y - self._dragStartY)
        camera.OrthogonalizeViewUp()

        renderer.ResetCameraClippingRange()
    
    def zoom(self, x: float, y: float):
        # from https://compucell3d.org/BinDoc/cc3d_binaries/dependencies/windows/MinGW/dependencies_qt_4.8.4_pyqt_4.9.6_vtk_5.10.1_python27/Player/vtk/wx/wxVTKRenderWindow.py
        
        renderer = self.renderer
        camera = renderer.GetActiveCamera()

        zoomFactor = math.pow(1.02,(0.5*(self._dragStartY - y)))
        self._CurrentZoom = self._CurrentZoom * zoomFactor

        if camera.GetParallelProjection():
            parallelScale = camera.GetParallelScale()/zoomFactor
            camera.SetParallelScale(parallelScale)
        else:
            camera.Dolly(zoomFactor)
            renderer.ResetCameraClippingRange()

        self._dragStartX = x
        self._dragStartY = y

        self.Render()
    
    
        
    
    def onToolChange(self, action):
        self.action = action.new
    
    def onFrameChange(self, action):
        self._currentFrame = action.new
        self.update()
    
    @output.capture()
    def selectCell(self, x: float, y: float):
        picker = vtk.vtkPropPicker()
        picker.Pick(x, y, 0, self.renderer)

        # get the new
        self.NewPickedActor = picker.GetActor()
        
        position = picker.GetPickPosition()
        
        if not picker.GetActor():
            self._selectedCell = None
            self.update()
            return
        
        x, z, y = picker.GetPickPosition()

        # If something was selected
        if self.NewPickedActor:
            # If we picked something before, reset its property
            if self.LastPickedActor:
                self.LastPickedActor.GetProperty().DeepCopy(self.LastPickedProperty)

            # Save the property of the picked actor so that we can
            self.LastPickedProperty.DeepCopy(self.NewPickedActor.GetProperty())
            # Highlight the picked actor by changing its properties
            self.NewPickedActor.GetProperty().SetColor(0.0, 0.0, 0.0)
            self.NewPickedActor.GetProperty().SetDiffuse(0.0)
            self.NewPickedActor.GetProperty().SetSpecular(0.0)
            
            self.LastPickedActor = self.NewPickedActor
            
        frame = self._parser.getFrame(self._currentFrame)
    
        cells = frame.cells.data
        cellVariables = frame.cells.variables
        
        distances = np.sqrt(np.square(x - cells[cellVariables['position.x']]) + np.square(y - cells[cellVariables['position.y']]) + np.square(z - cells[cellVariables['position.z']])) - self.radiusOfCells(cells, cellVariables)
        minIndex = np.argmin(distances)
        print(minIndex)
        
        if distances[minIndex] <= 0:
            self._selectedCell = cells[cellVariables['ID'], minIndex]
            
        self.update()
        
        
 
    def radiusOfCells(self, cells, variables):
        return (cells[variables['total_volume']] * (3 / ( 4 * math.pi))) ** (1 / 3)

    def show(self):
        display(self._canvas, self._buttons, self._frameSelector, output)
            



def InteractiveEnvironment(outputPath: str, width: int = 500, height: int = 400):
    parser = Parser(outputPath)
    if parser.getFrame(parser.getFrameRange()[0]).environment.is2D:
        return Interactor2D(parser, width, height)

# %%
Interactor3D(Parser('./sample-output')).show()
# Out:
# Canvas(height=400, width=500)
# RadioButtons(description='Mouse Action:', options=('move', 'rotate', 'zoom', 'select'), value='move')
# IntSlider(value=0, continuous_update=False, description='Frame:', max=9)
# Output()
